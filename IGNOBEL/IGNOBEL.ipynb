# %%
from utilities_IGNOBEL import *
with open('credential.json','r') as f:
    cred = json.load(f)
cluster = MongoClient(cred['cred'])
db = cluster['Game']
collection = db['Players']

# %%
collection.find_one({})
# Out:
# {'_id': 345,
#  'name': 'KEITA B.',
#  'info': {'personal_info': {'full_name': 'Keita Baldè',
#    'birthdate': '08/03/1995',
#    'nation': 'Spagna, Senegal',
#    'team_real': 'Sampdoria',
#    'FC_role': 'A',
#    'birthdate_num': 19950308},
#   'contract': {'owner': 'enzo',
#    'start_date': '2020/10/06',
#    'cost': 13,
#    'acquisition_mode': 'Algoritmo',
#    'previous_owner': None,
#    'quotation_initial': 13},
#   'current_team': {'owner': 'enzo',
#    'squad': 'main',
#    'start_date': '2020/10/06',
#    'previous_team': None,
#    'quotation_initial': '13',
#    'on_loan': False,
#    'loan_info': None},
#   'stats': {'Pg': 25,
#    'Mv': 6.0,
#    'Mf': 6.86,
#    'Gf': 7,
#    'Gs': 0,
#    'Rp': 0,
#    'Rc': 0,
#    'R+': 0,
#    'R-': 0,
#    'Ass': 1,
#    'Asf': 0,
#    'Amm': 4,
#    'Esp': 1,
#    'Au': 0,
#    'Qt_A': 18,
#    'Qt_I': 13}}}

# %%
"""Usare queste rose se FG non ha quelle corrette, e.g. durante il mercato"""
#RoseSS = rose_complete()

#RoseFG = rose()

#labels = RoseFG.columns
#Rose = RoseSS[labels]
# Out:
# 'Usare queste rose se FG non ha quelle corrette, e.g. durante il mercato'

# %%
#infortunati(giornata=1) #restituisce una singola lista con tutti gli infortunati di ogni squadra di serie A per la giornata indicata

# %%
#rose() #restituisce le rose attuali di ogni fantallenatore

# %%
#formazioni() #restituisce le formazioni schierate in ogni giornata (inclusa la panchina)

# %%
#per qualche strano motivo a volte da errore la prima volta che gira, 
#ma funziona le volte successive, potrebbe essere un caso
V = bonus_panchina(giornata=21) 
V
# restituisce i voti dei panchinari che non sono scesi in campo (link diverso temp)
# Out:
#                   IGNORANZA EVERYWHERE  MAINZ NA GIOIA  XYZ  AS 800A  \
# Bonus Panchinari                   0.5               0    0      1.5
#
#                   PALLA PAZZA  I DISEREDATI  SOROS FC  PDG 1908
# Bonus Panchinari            0           1.5         0         0

# %%
G = goal_subiti(giornata=21)
G
# restituisce il totale dei gol subiti da ogni portiere sceso in campo
# Out:
#              IGNORANZA EVERYWHERE  MAINZ NA GIOIA  XYZ  AS 800A  PALLA PAZZA  \
# Goal subiti                     1               2    2        0            0
#
#              I DISEREDATI  SOROS FC  PDG 1908
# Goal subiti             0         0         0

# %%
M = modificatore(giornata=21) 
M
# restituisce il bonus modificatore difesa guadagnato da ogni squadra
# Out:
#               IGNORANZA EVERYWHERE  MAINZ NA GIOIA  XYZ  AS 800A  PALLA PAZZA  \
# Modificatore                     0             0.5  0.5        0          1.5
#
#               I DISEREDATI  SOROS FC  PDG 1908
# Modificatore           1.5         0       1.5

# %%
C = cartellini(giornata=21)
C
# Out:
#            IGNORANZA EVERYWHERE  MAINZ NA GIOIA  XYZ  AS 800A  PALLA PAZZA  \
# C. gialli                     0               3    2        1            1
# C. rossi                      1               0    0        0            0
#
#            I DISEREDATI  SOROS FC  PDG 1908
# C. gialli             0         0         0
# C. rossi              0         0         0

# %%
CI = count_inf(infortunati(giornata = 28), rose()) #restituisce il numero di infortunati in ogni rosa
##NOTA: usa Rose definito sopra nel caso in cui FG non ha le rose corrette e quindi serve usare lo spreadsheet
CI
# Out:
#                  XYZ  MAINZ NA GIOIA  I DISEREDATI  PALLA PAZZA  AS 800A  \
# tot Infortunati    0               0             0            0        0
#
#                  PDG 1908  SOROS FC  IGNORANZA EVERYWHERE
# tot Infortunati         0         0                     0

# %%
infortunati(giornata = 28)
# Out:
# []

# %%
F = fantapunti_fatti(giornata=21)

# %%
S = fantapunti_subiti(giornata=21)

# %%
#tot = IGNOBEL_tot(giornata=6) # a causa di ritardi di connessione, potrebbe dare errore le prime volte: in tal caso far girare nuovamente
output = pd.concat([F,S,G,C,V,M,CI], axis = 0).T #enormi problemi di connessione, quindi ho dovuto dividere in singole tasks
tot = output.T
tot
# Out:
#                    IGNORANZA EVERYWHERE  MAINZ NA GIOIA    XYZ  AS 800A  \
# Fantapunti Fatti                   64.0            69.0  64.00    71.25
# Fantapunti Subiti                  69.0            64.0  71.25    64.00
# Goal subiti                         1.0             2.0   2.00     0.00
# C. gialli                           0.0             3.0   2.00     1.00
# C. rossi                            1.0             0.0   0.00     0.00
# Bonus Panchinari                    0.5             0.0   0.00     1.50
# Modificatore                        0.0             0.5   0.50     0.00
# tot Infortunati                     4.0             4.0   1.00     4.00
#
#                    PALLA PAZZA  I DISEREDATI  SOROS FC  PDG 1908
# Fantapunti Fatti         72.75         75.50     67.50     72.75
# Fantapunti Subiti        75.50         72.75     72.75     67.50
# Goal subiti               0.00          0.00      0.00      0.00
# C. gialli                 1.00          0.00      0.00      0.00
# C. rossi                  0.00          0.00      0.00      0.00
# Bonus Panchinari          0.00          1.50      0.00      0.00
# Modificatore              1.50          1.50      0.00      1.50
# tot Infortunati           1.00          4.00      2.00      5.00

# %%
giornata=35
tot = IGNOBEL_tot(giornata)
tot
# Out:
#                    IGNORANZA EVERYWHERE  MAINZ NA GIOIA    XYZ  AS 800A  \
# Fantapunti Fatti                  64.25           77.00  68.25    71.75
# Fantapunti Subiti                 77.00           64.25  71.75    68.25
# Goal subiti                        2.00            0.00   2.00     0.00
# C. gialli                          1.00            2.00   1.00     1.00
# C. rossi                           0.00            0.00   0.00     0.00
# Bonus Panchinari                   3.00            0.50   1.50     0.00
# Modificatore                       0.00            1.00   0.50     0.50
# tot Infortunati                    0.00            0.00   0.00     0.00
#
#                    PALLA PAZZA  I DISEREDATI  SOROS FC  PDG 1908
# Fantapunti Fatti          62.5          74.0     68.75     70.75
# Fantapunti Subiti         74.0          62.5     70.75     68.75
# Goal subiti                0.0           1.0      1.00      0.00
# C. gialli                  0.0           1.0      1.00      0.00
# C. rossi                   0.0           0.0      0.00      0.00
# Bonus Panchinari           1.5           0.0      1.50      0.75
# Modificatore               0.0           2.0      1.50      0.00
# tot Infortunati            0.0           0.0      0.00      0.00

# %%
tot.to_pickle("Dati_storici/Giornata_"+str(giornata)+".pkl")
#crea 8 dataframe individuali con i dati aggiornati fino alla giornata indicata
aggiorna_database(giornata)
# Out:
# Dati aggiornati fino alla 35 giornata

# %%
G = pd.read_pickle("Dati_storici/Giornata_22.pkl")
G
# Out:
#                    PDG 1908  AS 800A  SOROS FC  IGNORANZA EVERYWHERE  \
# Fantapunti Fatti      72.00    72.25     65.75                 71.75
# Fantapunti Subiti     72.25    72.00     71.75                 65.75
# Goal subiti            2.00     1.00      3.00                  0.00
# C. gialli              1.00     1.00      0.00                  1.00
# C. rossi               0.00     0.00      0.00                  0.00
# Bonus Panchinari       0.00     2.25      3.50                  0.00
# Modificatore           0.50     0.00      0.00                  1.50
# tot Infortunati        4.00     4.00      2.00                  4.00
#
#                    PALLA PAZZA  MAINZ NA GIOIA    XYZ  I DISEREDATI
# Fantapunti Fatti         68.50           71.75  75.75         73.25
# Fantapunti Subiti        71.75           68.50  73.25         75.75
# Goal subiti               0.00            1.00   0.00          1.00
# C. gialli                 0.00            1.00   1.00          1.00
# C. rossi                  0.00            0.00   0.00          0.00
# Bonus Panchinari          1.50            1.00   0.00          3.00
# Modificatore              1.00            0.50   1.50          1.00
# tot Infortunati           1.00            4.00   2.00          4.00

# %%
#voti_all = scarica_voti(giornata = 3, stagione = '2020-21')
#scarica il dataframe con tutti i voti direttamente da fantacalcio.it

# %%
storico_individuale(nome = 'luca', giornata = 22) 
#crea un dataframe individuale con le informazioni utili per gli IGNOBEL, con i dati fino alla giornata scelta
#i dati vengono pescati dai pkl contenuti nella cartella Dati_storici
# Out:
# 0   gg     pf     ps gs  c   pan  mod inf  nome
# 1    1  72.25   67.5  0  6     0    0   7  luca
# 2    2     77  64.25  2  1     0    0   5  luca
# 3    3   73.5   70.5  1  2  1.75    0   3  luca
# 4    4     65     65  0  2     3  0.5   4  luca
# 5    5     66  67.25  2  2     0    0   4  luca
# 6    6  70.25     71  1  2   1.5  0.5   5  luca
# 7    7     69  67.25  1  1   1.5    0   4  luca
# 8    8  69.75  73.75  1  2   0.5    0   3  luca
# 9    9   66.5   62.5  2  4     1    0   2  luca
# 10  10  67.25  70.75  1  1     0    1   2  luca
# 11  11  67.75  69.25  2  1   1.5    0   3  luca
# 12  12   74.5  72.25  0  2     0  1.5   4  luca
# 13  13   67.5  73.75  0  2   0.5    1   4  luca
# 14  14  71.75     73  1  2     0    1   4  luca
# 15  15     80  68.25  0  3   1.5    1   3  luca
# 16  16     71  73.25  1  0   1.5    0   1  luca
# 17  17  63.75     64  3  1     0  0.5   2  luca
# 18  18   69.5  71.25  2  3   1.5  0.5   3  luca
# 19  19     69  74.75  1  2  0.25  0.5   2  luca
# 20  20   65.5  77.25  2  2     0  0.5   1  luca
# 21  21     64  71.25  2  2     0  0.5   1  luca
# 22  22  75.75  73.25  0  1     0  1.5   2  luca

# %%
#include svincolati
#ST = stats_by_team_full(primavera = True)
ST_INFO = stats_by_team_NO_INFO(primavera = True) #NO PERSONAL DATA
missing_pl = info_missing_players(collection, ST_INFO) #missing players from our db

# %%
ST_INFO
# Out:
#         Id  R          Nome   Squadra  Pg    Mv    Mf  Gf  Gs  Rp  ...  Ass  \
# 507    507  A        MURIEL  Atalanta  36  6.67  8.92  20   0   0  ...    8
# 2531  2531  A        LUKAKU     Inter  36  6.63  8.89  18   0   0  ...    9
# 2610  2610  A       RONALDO  Juventus  33  6.32  8.79  23   0   0  ...    2
# 531    531  A       BERARDI  Sassuolo  30  6.60  8.37  10   0   0  ...    6
# 409    409  A       INSIGNE    Napoli  35  6.53  8.21  12   0   0  ...    6
# ...    ... ..           ...       ...  ..   ...   ...  ..  ..  ..  ...  ...
# 5378  5378  A         ODDEI  Sassuolo   5  6.17  6.83   0   0   0  ...    2
# 5060  5060  A       AKE' M.  Juventus   0  0.00  0.00   0   0   0  ...    0
# 5414  5414  A  KARAMOKO IS.  Sassuolo   1  0.00  0.00   0   0   0  ...    0
# 5419  5419  A       CORREIA  Juventus   1  0.00  0.00   0   0   0  ...    0
# 5436  5436  A      RAIMONDO   Bologna   1  0.00  0.00   0   0   0  ...    0
#
#       Asf  Amm  Esp  Au  Qt. A  Qt. I  Diff.  Nome Squadra  Allenatore
# 507     1    0    0   0     43     27     16      PDG 1908      pietro
# 2531    0    4    0   0     43     42      1      SOROS FC      musci8
# 2610    0    3    0   0     42     48     -6       AS 800A        enzo
# 531     1    4    0   0     38     27     11  I DISEREDATI    emiliano
# 409     1    2    1   0     36     23     13           XYZ        luca
# ...   ...  ...  ...  ..    ...    ...    ...           ...         ...
# 5378    0    0    0   0      1      1      0    svincolato        None
# 5060    0    0    0   0      1      1      0    svincolato        None
# 5414    0    0    0   0      1      1      0    svincolato        None
# 5419    0    0    0   0      1      1      0    svincolato        None
# 5436    0    0    0   0      1      1      0    svincolato        None
#
# [564 rows x 23 columns]

# %%
ST_INFO.rename(columns = {'Qt. A': 'Qt_A','Qt. I': 'Qt_I'}, inplace=True)
ST_INFO.to_pickle("Statistiche_giocatori.pkl")
missing_pl.to_pickle('Missing_Players.pkl')
ST_INFO
# Out:
#         Id  R          Nome   Squadra  Pg    Mv    Mf  Gf  Gs  Rp  ...  Ass  \
# 507    507  A        MURIEL  Atalanta  36  6.67  8.92  20   0   0  ...    8
# 2531  2531  A        LUKAKU     Inter  36  6.63  8.89  18   0   0  ...    9
# 2610  2610  A       RONALDO  Juventus  33  6.32  8.79  23   0   0  ...    2
# 531    531  A       BERARDI  Sassuolo  30  6.60  8.37  10   0   0  ...    6
# 409    409  A       INSIGNE    Napoli  35  6.53  8.21  12   0   0  ...    6
# ...    ... ..           ...       ...  ..   ...   ...  ..  ..  ..  ...  ...
# 5378  5378  A         ODDEI  Sassuolo   5  6.17  6.83   0   0   0  ...    2
# 5060  5060  A       AKE' M.  Juventus   0  0.00  0.00   0   0   0  ...    0
# 5414  5414  A  KARAMOKO IS.  Sassuolo   1  0.00  0.00   0   0   0  ...    0
# 5419  5419  A       CORREIA  Juventus   1  0.00  0.00   0   0   0  ...    0
# 5436  5436  A      RAIMONDO   Bologna   1  0.00  0.00   0   0   0  ...    0
#
#       Asf  Amm  Esp  Au  Qt_A  Qt_I  Diff.  Nome Squadra  Allenatore
# 507     1    0    0   0    43    27     16      PDG 1908      pietro
# 2531    0    4    0   0    43    42      1      SOROS FC      musci8
# 2610    0    3    0   0    42    48     -6       AS 800A        enzo
# 531     1    4    0   0    38    27     11  I DISEREDATI    emiliano
# 409     1    2    1   0    36    23     13           XYZ        luca
# ...   ...  ...  ...  ..   ...   ...    ...           ...         ...
# 5378    0    0    0   0     1     1      0    svincolato        None
# 5060    0    0    0   0     1     1      0    svincolato        None
# 5414    0    0    0   0     1     1      0    svincolato        None
# 5419    0    0    0   0     1     1      0    svincolato        None
# 5436    0    0    0   0     1     1      0    svincolato        None
#
# [564 rows x 23 columns]

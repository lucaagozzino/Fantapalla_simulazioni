# %%
from utilities_IGNOBEL import *

# %%
"""Usare queste rose se FG non ha quelle corrette, e.g. durante il mercato"""
#RoseSS = rose_complete()

#RoseFG = rose()

#labels = RoseFG.columns
#Rose = RoseSS[labels]
# Out:
# 'Usare queste rose se FG non ha quelle corrette, e.g. durante il mercato'

# %%
#infortunati(giornata=1) #restituisce una singola lista con tutti gli infortunati di ogni squadra di serie A per la giornata indicata

# %%
#rose() #restituisce le rose attuali di ogni fantallenatore

# %%
#formazioni() #restituisce le formazioni schierate in ogni giornata (inclusa la panchina)

# %%
#per qualche strano motivo a volte da errore la prima volta che gira, 
#ma funziona le volte successive, potrebbe essere un caso
V = bonus_panchina(giornata=7) 
V
# restituisce i voti dei panchinari che non sono scesi in campo (link diverso temp)
# Out:
#                   IGNORANZA EVERYWHERE  MAINZ NA GIOIA  XYZ  AS 800A  \
# Bonus Panchinari                     0               0  1.5      3.0
#
#                   PALLA PAZZA  I DISEREDATI  SOROS FC  PDG 1908
# Bonus Panchinari            0           1.5         0       2.0

# %%
G = goal_subiti(giornata=7)
G
# restituisce il totale dei gol subiti da ogni portiere sceso in campo
# Out:
#              IGNORANZA EVERYWHERE  MAINZ NA GIOIA  XYZ  AS 800A  PALLA PAZZA  \
# Goal subiti                     1               1    1        1            0
#
#              I DISEREDATI  SOROS FC  PDG 1908
# Goal subiti             4         0         1

# %%
M = modificatore(giornata=7) 
M
# restituisce il bonus modificatore difesa guadagnato da ogni squadra
# Out:
#               IGNORANZA EVERYWHERE  MAINZ NA GIOIA  XYZ  AS 800A  PALLA PAZZA  \
# Modificatore                   1.0               0    0      1.0          1.0
#
#               I DISEREDATI  SOROS FC  PDG 1908
# Modificatore           0.5         0         0

# %%
C = cartellini(giornata=7)
C
# Out:
#            IGNORANZA EVERYWHERE  MAINZ NA GIOIA  XYZ  AS 800A  PALLA PAZZA  \
# C. gialli                     2               1    1        3            1
# C. rossi                      0               1    0        0            0
#
#            I DISEREDATI  SOROS FC  PDG 1908
# C. gialli             0         0         1
# C. rossi              0         0         0

# %%
CI = count_inf(infortunati(giornata = 7), rose()) #restituisce il numero di infortunati in ogni rosa
##NOTA: usa Rose definito sopra nel caso in cui FG non ha le rose corrette e quindi serve usare lo spreadsheet
CI
# Out:
#                  XYZ  MAINZ NA GIOIA  I DISEREDATI  PALLA PAZZA  AS 800A  \
# tot Infortunati    4               6             5            6        5
#
#                  PDG 1908  SOROS FC  IGNORANZA EVERYWHERE
# tot Infortunati         1         2                     6

# %%
F = fantapunti_fatti(giornata=7)

# %%
S = fantapunti_subiti(giornata=7)

# %%
#tot = IGNOBEL_tot(giornata=6) # a causa di ritardi di connessione, potrebbe dare errore le prime volte: in tal caso far girare nuovamente
output = pd.concat([F,S,G,C,V,M,CI], axis = 0).T #enormi problemi di connessione, quindi ho dovuto dividere in singole tasks
tot = output.T
tot
# Out:
#                    IGNORANZA EVERYWHERE  MAINZ NA GIOIA    XYZ  AS 800A  \
# Fantapunti Fatti                  66.50           69.75  69.00    67.25
# Fantapunti Subiti                 69.75           66.50  67.25    69.00
# Goal subiti                        1.00            1.00   1.00     1.00
# C. gialli                          2.00            1.00   1.00     3.00
# C. rossi                           0.00            1.00   0.00     0.00
# Bonus Panchinari                   0.00            0.00   1.50     3.00
# Modificatore                       1.00            0.00   0.00     1.00
# tot Infortunati                    6.00            6.00   4.00     5.00
#
#                    PALLA PAZZA  I DISEREDATI  SOROS FC  PDG 1908
# Fantapunti Fatti         75.00         66.75     69.50     69.25
# Fantapunti Subiti        66.75         75.00     69.25     69.50
# Goal subiti               0.00          4.00      0.00      1.00
# C. gialli                 1.00          0.00      0.00      1.00
# C. rossi                  0.00          0.00      0.00      0.00
# Bonus Panchinari          0.00          1.50      0.00      2.00
# Modificatore              1.00          0.50      0.00      0.00
# tot Infortunati           6.00          5.00      2.00      1.00

# %%
tot = IGNOBEL_tot(giornata=17)
tot
# Out:
#                    IGNORANZA EVERYWHERE    XYZ  MAINZ NA GIOIA  PDG 1908  \
# Fantapunti Fatti                  64.00  63.75           78.25     70.50
# Fantapunti Subiti                 63.75  64.00           70.50     78.25
# Goal subiti                        0.00   3.00            1.00      0.00
# C. gialli                          0.00   1.00            3.00      0.00
# C. rossi                           1.00   0.00            0.00      1.00
# Bonus Panchinari                   0.50   0.00            1.25      1.50
# Modificatore                       1.00   0.50            1.50      0.00
# tot Infortunati                    2.00   2.00            4.00      1.00
#
#                    I DISEREDATI  AS 800A  PALLA PAZZA  SOROS FC
# Fantapunti Fatti           67.0     71.0        68.25     69.50
# Fantapunti Subiti          71.0     67.0        69.50     68.25
# Goal subiti                 0.0      0.0         1.00      0.00
# C. gialli                   2.0      1.0         0.00      0.00
# C. rossi                    0.0      0.0         0.00      1.00
# Bonus Panchinari            0.0      0.5         3.00      4.50
# Modificatore                1.5      0.0         0.50      0.00
# tot Infortunati             4.0      1.0         3.00      0.00

# %%
tot.to_pickle("Dati_storici/Giornata_17.pkl")

# %%
G = pd.read_pickle("Dati_storici/Giornata_16.pkl")
G
# Out:
#                    PDG 1908  I DISEREDATI    XYZ  MAINZ NA GIOIA  PALLA PAZZA  \
# Fantapunti Fatti      72.25         64.50  71.00           73.25         70.0
# Fantapunti Subiti     64.50         72.25  73.25           71.00         67.5
# Goal subiti            1.00          0.00   1.00            3.00          3.0
# C. gialli              2.00          0.00   0.00            1.00          2.0
# C. rossi               0.00          0.00   0.00            0.00          0.0
# Bonus Panchinari       0.00          0.00   1.50            0.00          2.0
# Modificatore           0.00          0.50   0.00            1.50          0.5
# tot Infortunati        3.00          2.00   1.00            3.00          3.0
#
#                    IGNORANZA EVERYWHERE  SOROS FC  AS 800A
# Fantapunti Fatti                   67.5     71.75    69.25
# Fantapunti Subiti                  70.0     69.25    71.75
# Goal subiti                         0.0      3.00     0.00
# C. gialli                           2.0      3.00     3.00
# C. rossi                            0.0      0.00     0.00
# Bonus Panchinari                    0.0      0.50     1.25
# Modificatore                        0.5      0.00     0.00
# tot Infortunati                     0.0      2.00     1.00

# %%
#voti_all = scarica_voti(giornata = 3, stagione = '2020-21')
#scarica il dataframe con tutti i voti direttamente da fantacalcio.it

# %%
storico_individuale(nome = 'luca', giornata = 16) 
#crea un dataframe individuale con le informazioni utili per gli IGNOBEL, con i dati fino alla giornata scelta
#i dati vengono pescati dai pkl contenuti nella cartella Dati_storici
# Out:
# 0   gg     pf     ps gs  c   pan  mod inf  nome
# 1    1  72.25   67.5  0  6     0    0   7  luca
# 2    2     77  64.25  2  1     0    0   5  luca
# 3    3   73.5   70.5  1  2  1.75    0   3  luca
# 4    4     65     65  0  2     3  0.5   4  luca
# 5    5     66  67.25  2  2     0    0   4  luca
# 6    6  70.25     71  1  2   1.5  0.5   5  luca
# 7    7     69  67.25  1  1   1.5    0   4  luca
# 8    8  69.75  73.75  1  2   0.5    0   3  luca
# 9    9   66.5   62.5  2  4     1    0   2  luca
# 10  10  67.25  70.75  1  1     0    1   2  luca
# 11  11  67.75  69.25  2  1   1.5    0   3  luca
# 12  12   74.5  72.25  0  2     0  1.5   4  luca
# 13  13   67.5  73.75  0  2   0.5    1   4  luca
# 14  14  71.75     73  1  2     0    1   4  luca
# 15  15     80  68.25  0  3   1.5    1   3  luca
# 16  16     71  73.25  1  0   1.5    0   1  luca

# %%
#crea 8 dataframe individuali con i dati aggiornati fino alla giornata indicata
aggiorna_database(giornata = 17)
# Out:
# Dati aggiornati fino alla 17 giornata

# %%
#scarica le statistiche di ogni giocatori e li incrocia con le rose nel database FPF per associarli ad ogni squadra nella lega
#ST = stats_by_team(primavera = True, personal = True)
#ST.to_pickle("Statistiche_giocatori.pkl")
#ST

# %%
personal_info('MUSSO', ST)
# Out:
# ('06/05/1994', '26', 'Musso Juan', 'Argentina, Italia')

# %%
#include svincolati
ST = stats_by_team_full(primavera = True)

# %%
ST.rename(columns = {'Qt. A': 'Qt_A','Qt. I': 'Qt_I'}, inplace=True)
ST.to_pickle("Statistiche_giocatori.pkl")
ST
# Out:
#        Id  R           Nome   Squadra  Pg    Mv    Mf  Gf  Gs  Rp  ...  Au  \
# 0    2610  A        RONALDO  Juventus  16  6.34  9.09  11   0   0  ...   0
# 1    2531  A         LUKAKU     Inter  19  6.61  8.97  11   0   0  ...   0
# 2     785  A       IMMOBILE     Lazio  18  6.56  8.61  10   0   0  ...   0
# 3     507  A         MURIEL  Atalanta  18  6.70  9.03  10   0   0  ...   0
# 4     441  A        BELOTTI    Torino  19  6.68  8.45   8   0   0  ...   0
# ..    ... ..            ...       ...  ..   ...   ...  ..  ..  ..  ...  ..
# 541  5303  A          MALES     Genoa   0  0.00  0.00   0   0   0  ...   0
# 542  4335  A  SCHIAPPACASSE  Sassuolo   1  6.00  6.00   0   0   0  ...   0
# 543  4938  A           MORO     Lazio   0  0.00  0.00   0   0   0  ...   0
# 544  5361  A          RABBI   Bologna   4  0.00  0.00   0   0   0  ...   0
# 545  5060  A        AKE' M.  Juventus   0  0.00  0.00   0   0   0  ...   0
#
#      Qt_A  Qt_I  Diff.      Classe  Eta'          Nome Completo  \
# 0      47    48     -1  05/02/1985    36      Cristiano Ronaldo
# 1      45    42      3  13/03/1993    28          Lukaku Romelu
# 2      42    49     -7  20/02/1990    31          Immobile Ciro
# 3      37    27     10  16/04/1991    30            Muriel Luis
# 4      37    29      8  20/12/1993    28         Belotti Andrea
# ..    ...   ...    ...         ...   ...                    ...
# 541     1     1      0  03/05/2001    20           Males Darian
# 542     1     1      0  12/01/1999    22  Schiappacasse Nicolas
# 543     1     1      0  05/12/2002    19              Moro Raul
# 544     1     1      0  30/10/2001    20           Rabbi Simone
# 545     1     1      0  05/01/2001    20             Akè Marley
#
#                                  Nazionalit'a          Nome Squadra  \
# 0                                  Portogallo               AS 800A
# 1    Belgio, Repubblica Democratica del Congo              SOROS FC
# 2                                      Italia           PALLA PAZZA
# 3                                    Colombia              PDG 1908
# 4                                      Italia                   XYZ
# ..                                        ...                   ...
# 541                          Svizzera, Serbia            svincolato
# 542                           Uruguay, Italia  SOROS FC - PRIMAVERA
# 543                                    Spagna            svincolato
# 544                                    Italia            svincolato
# 545                   Francia, Costa d'Avorio            svincolato
#
#      Allenatore
# 0          enzo
# 1        musci8
# 2         nanni
# 3        pietro
# 4          luca
# ..          ...
# 541        None
# 542      musci8
# 543        None
# 544        None
# 545        None
#
# [546 rows x 27 columns]

# %%
#web scraping

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import pandas as pd

options = Options()
options.headless = True
options.add_argument("--window-size=1920,10200") #this is important, to tell it how much of the webpage to import
driver = webdriver.Chrome(options=options, executable_path=r'/usr/local/bin/chromedriver')

# %%
#rivedere i vari xpath, nel caso in cui la struttura del sito e' diversa

def scarica_formazioni(link):
    driver.get(link)
    formazioni = {}
    
    for l in [2,3,4,5]:
        for k in [1,2]:
            temp = []
            for i in range(1,12):
                test = driver.find_element_by_xpath('/html/body/div[7]/main/div[3]/div[2]/div[1]/div[1]/div/div/div['+str(l)+']/div[2]/div['+str(k)+']/table[1]/tbody/tr['+str(i)+']/td[1]/span/span[2]/a')
                team_name = driver.find_element_by_xpath('/html/body/div[7]/main/div[3]/div[2]/div[1]/div[1]/div/div/div['+str(l)+']/div[1]/div['+str(k)+']/div/div[2]/h4')
                temp.append(test.text)
            for j in range(1,8):
                test = driver.find_element_by_xpath('/html/body/div[7]/main/div[3]/div[2]/div[1]/div[1]/div/div/div['+str(l)+']/div[2]/div['+str(k)+']/table[2]/tbody/tr['+str(j)+']/td[1]/span/span[2]/a')
                #test = driver.find_element_by_xpath('/html/body/div[7]/main/div[3]/div[2]/div[1]/div[1]/div/div/div[2]/div[2]/div[2]/table[2]/tbody/tr['+str(j)+']/td[1]/span/span[2]/a')
                temp.append(test.text)
            formazioni[team_name.text]= temp
            
    return pd.DataFrame(data=formazioni)

# %%
scarica_formazioni("https://leghe.fantacalcio.it/fantapalla/formazioni")#prova su lega random
# Out:
#        Real Mortazza      Reloaded      Vesuvio     TeeCRo 7  Team Bukowski  \
# 0          Strakosha    Handanovic     Szczesny       Buffon          Perin
# 1            Rogerio        Acerbi     Cuadrado      Mancini       Iacoponi
# 2               Glik       Kolarov  Bruno Alves    Zeegelaar       Biraschi
# 3             Acerbi      Criscito     Criscito   Spinazzola        Rispoli
# 4             Badelj      Veretout     Politano     Cuadrado       Veretout
# 5                Rog         Marin       Pulgar      Hernani          Kucka
# 6   Milinkovic-Savic  Luis Alberto       Rabiot    Zielinski           Zajc
# 7            Barella      Bennacer   Kulusevski     Djuricic   Luis Alberto
# 8           Immobile     Bonazzoli      Osimhen      Osimhen     Joao Pedro
# 9            Osimhen        Lukaku        Dzeko      Ronaldo       Immobile
# 10            Lukaku         Milik      Mertens  Ibrahimovic         Lukaku
# 11             Reina       Radu I.       Buffon     Szczesny      Marchetti
# 12         Lukaku J.        Ibanez      Kolarov        Conti      Mattiello
# 13     Pezzella Ger.       Demiral     Calabria       Maggio          Cetin
# 14            Nandez       Khedira      Sturaro      Hetemaj       Ricci M.
# 15           De Roon        Ramsey         Poli   Di Carmine  Schiattarella
# 16         Raspadori      Lapadula   Insigne R.     Haraslin           Simy
# 17          Scamacca     Calafiori    Galabinov     Acampora       Adekanye
#
#        ZIO ZLATAN Real Cozzari Atletici Finidi
# 0   Donnarumma G.   Handanovic   Donnarumma G.
# 1         Mancini      Biraghi         Biraghi
# 2           Kjaer    Zeegelaar        Iacoponi
# 3      Milenkovic         Glik           Zappa
# 4            Jony       Hakimi      Calhanoglu
# 5         Kessie'        Kucka     Malinovskyi
# 6       Bentancur     Ricci M.          Nandez
# 7          Rabiot   Mkhitaryan         De Paul
# 8          Lukaku       Lukaku         Belotti
# 9           Dzeko         Simy          Lukaku
# 10     Di Carmine      Ronaldo          Barrow
# 11     Tatarusanu   Sportiello      Tatarusanu
# 12         Laxalt  Lykogiannis       Marchizza
# 13       Crociata    Mattiello         Agudelo
# 14         Arthur      Agudelo          Meite'
# 15      Zanellato   Cristoforo         Kouame'
# 16         Juwara    Stepinski         Piccoli
# 17         Gabbia       Kargbo          Gabbia

# %%
scarica_formazioni('https://leghe.fantacalcio.it/juventus/formazioni')#prova su lega random
# Out:
#    S.S. DeLaurentiis     Delirium   Piangina United Bin Laden U S - a  \
# 0         Handanovic       Cragno         Silvestri            Audero
# 1         Di Lorenzo       Hakimi            Gosens          Criscito
# 2          Koulibaly     Calabria          Nuytinck           Bonucci
# 3            Kolarov      Faraoni           Manolas           Dimarco
# 4          Berenguer   Castillejo          Cuadrado          Hateboer
# 5            De Paul      Eriksen            Ramsey             Kucka
# 6            Kessie'   Mkhitaryan  Milinkovic-Savic          Ricci M.
# 7        Malinovskyi     Djuricic     Douglas Costa           Perisic
# 8             Barrow     Lapadula            Muriel        Di Carmine
# 9            Simeone      Belotti            Lukaku          Immobile
# 10           Ronaldo      Mertens           Inglese      Quagliarella
# 11              Sepe      Mirante          Szczesny             Perin
# 12           Bastoni      Kouame'           Ansaldi        Spinazzola
# 13           Vojvoda       Jankto            Ibanez           Biraghi
# 14           Pasalic        Verdi            Nandez          Politano
# 15         Locatelli      Agudelo           Amrabat           Soriano
# 16            Schone  Danilo Lar.           Lasagna            Rabiot
# 17            Correa         Glik              Zaza            Pandev
#
#        PVX MEA LVX      As Tronzi Inter del Triplete   FrauBotta
# 0        Skorupski  Donnarumma G.           Consigli       Musso
# 1            Young   Hernandez T.      Kyriakopoulos  Zappacosta
# 2            Toloi      Ghiglione           N'Koulou   Chiellini
# 3            Kjaer       Tomiyasu           Kumbulla  Milenkovic
# 4            Godin       Palomino             Acerbi        Radu
# 5   Pellegrini Lo.   Luis Alberto             Sottil        Ruiz
# 6        Zielinski          Gomez         Calhanoglu      Chiesa
# 7          Barella        Ramirez        Castrovilli  Kulusevski
# 8          Caprari      Zapata D.        Martinez L.       Dzeko
# 9          Insigne         Ribery            Osimhen      Caputo
# 10         Berardi          Rebic         Joao Pedro  Gabbiadini
# 11       Dragowski     Tatarusanu             Sirigu  Sportiello
# 12    De Silvestri       Orsolini        Bereszynski   Mario Rui
# 13         Mancini           Simy              Vidal        Izzo
# 14       Bentancur        Linetty              Demme      Tonali
# 15     Bonaventura           Zajc        Lucas Leiva     Lazzari
# 16           Pedro        Letizia             Dybala     Freuler
# 17             Rog        Demiral            Sanchez     Palacio

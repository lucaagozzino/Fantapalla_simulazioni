# %%
#test github 2
import numpy as np
import pandas as pd
from Utilities_fantapalla import main_model, names, styling_rows

quotazioni = pd.read_csv ('Quotazioni_Fantacalcio.csv')
# il file quotazioni contiene la lista dei giocatori direttamente da fantacalcio.it, che non ha i dati (in .gitignore)
# perfettamente aggiornati alcuni giocatori sono gia' fuori (tipo higuahin) o infortunati (tipo zaniolo), 
# quindi dobbiamo rimuovere a mano quelli che non ci interessano 
path_voti = 'Voti_giornate/'
rows_to_skip=[0,1,2,3,4]
# i voti sono quelli delle 38 giornate del campionato 2019/2020

# %%
# struttura della rosa [por, dif, cen, att]
struttura_rosa = np.array([3, 8, 8, 6])

# quali formazioni sono permesse
formazioni = {
    '352': [1, 3, 5, 2],
    '343': [1, 3, 4, 3],
    '442': [1, 4, 4, 2],
    '541': [1, 5, 4, 1],
    '532': [1, 5, 3, 2],
    '433': [1, 4, 3, 3]
    #aggiungere tutte le altre formazioni
}
fasce_goal = np.array([66,  70,  84,  88,  92,  96, 100])
fasce_modificatore = np.array([6. , 6.5, 7. , 7.5, 8. ])
valori_modificatore = np.array([1, 3, 5, 6, 8])

N_squadre = 8

# quanti campionati simulare
N_campionati = 2

[teams, team_names] = names(N_squadre) # output ridondanti ma mi seccavo modificare il resto

# %%
rose_best, classifica_best, classifica_q_best = main_model(N_campionati, struttura_rosa, team_names, teams, quotazioni, path_voti, N_squadre, valori_modificatore, fasce_modificatore, fasce_goal, formazioni)
# Out:
# N/A% (0 of 2) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--

# %%
classifica_best

# %%
rose_best

# %%
#rose_best.to_pickle('rose_best.pkl')
rose_best = pd.read_pickle('rose_best.pkl')

# %%
rose_best.style.apply(styling_rows, struttura = struttura_rosa, axis = None)
# Out:
# <style  type="text/css" >
#     #T_cc1bc9d6_f757_11ea_be8b_acde48001122row0_col0 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row0_col1 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row0_col2 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row0_col3 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row0_col4 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row0_col5 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row0_col6 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row0_col7 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row1_col0 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row1_col1 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row1_col2 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row1_col3 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row1_col4 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row1_col5 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row1_col6 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row1_col7 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row2_col0 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row2_col1 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row2_col2 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row2_col3 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row2_col4 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row2_col5 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row2_col6 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row2_col7 {
#             background-color:  orange;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row3_col0 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row3_col1 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row3_col2 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row3_col3 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row3_col4 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row3_col5 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row3_col6 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row3_col7 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row4_col0 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row4_col1 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row4_col2 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row4_col3 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row4_col4 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row4_col5 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row4_col6 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row4_col7 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row5_col0 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row5_col1 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row5_col2 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row5_col3 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row5_col4 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row5_col5 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row5_col6 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row5_col7 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row6_col0 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row6_col1 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row6_col2 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row6_col3 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row6_col4 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row6_col5 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row6_col6 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row6_col7 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row7_col0 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row7_col1 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde48001122row7_col2 {
#             background-color:  darkseagreen;
#              color:  black;
#         }    #T_cc1bc9d6_f757_11ea_be8b_acde

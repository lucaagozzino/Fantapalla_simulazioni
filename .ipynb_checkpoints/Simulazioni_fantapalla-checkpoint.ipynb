# %%
#test github 2
import numpy as np
import pandas as pd
from Utilities_fantapalla import main_model, names

quotazioni = pd.read_csv ('Quotazioni_Fantacalcio.csv')
# il file quotazioni contiene la lista dei giocatori direttamente da fantacalcio.it, che non ha i dati (in .gitignore)
# perfettamente aggiornati alcuni giocatori sono gia' fuori (tipo higuahin) o infortunati (tipo zaniolo), 
# quindi dobbiamo rimuovere a mano quelli che non ci interessano 
path_voti = 'Voti_giornate/'
rows_to_skip=[0,1,2,3,4]
# i voti sono quelli delle 38 giornate del campionato 2019/2020

# %%
# struttura della rosa [por, dif, cen, att]
struttura_rosa = np.array([3, 8, 8, 6])

# quali formazioni sono permesse
formazioni = {
    '352': [1, 3, 5, 2],
    '343': [1, 3, 4, 3],
    '442': [1, 4, 4, 2],
    '541': [1, 5, 4, 1],
    '532': [1, 5, 3, 2],
    '433': [1, 4, 3, 3]
    #aggiungere tutte le altre formazioni
}
fasce_goal = np.array([66,  70,  84,  88,  92,  96, 100])
fasce_modificatore = np.array([6. , 6.5, 7. , 7.5, 8. ])
valori_modificatore = np.array([1, 3, 5, 6, 8])

N_squadre = 8

# quanti campionati simulare
N_campionati = 1

[teams, team_names] = names(N_squadre) # output ridondanti ma mi seccavo modificare il resto

# %%
rose_best, classifica_best, classifica_q_best = main_model(N_campionati, struttura_rosa, team_names, teams, quotazioni, path_voti, N_squadre, valori_modificatore, fasce_modificatore, fasce_goal, formazioni)
# Out:
# [6.5 6.5 7.  7. ]e:1
# [6.5 6.5 7.  7. ]
# [6.5 6.5 7.  7. ]
# [6.5 6.5 7.  7. ]
# [6.5 6.5 7.  0. ]
# [6.5 6.5 7.  0. ]
# [6.5 6.5 7.  0. ]
# [6.5 6.5 7.  0. ]
# [6.  6.5 6.5 6. ]
# [6.  6.5 6.5 6. ]
# [6.  6.5 6.5 6. ]
# [6.  6.5 6.5 6. ]
# [7.  7.  7.  7.5]
# [7.  7.  7.  7.5]
# [7.  7.  7.  7.5]
# [7.  7.  7.  7.5]
# [6.  6.5 6.5 7. ]
# [6.  6.5 6.5 7. ]
# [6.  6.5 6.5 7. ]
# [6.  6.5 6.5 7. ]
# [6. 6. 7. 6.]
# [6. 6. 7. 6.]
# [6. 6. 7. 6.]
# [6. 6. 7. 6.]
# [6.5 6.5 6.5 7.5]
# [6.5 6.5 6.5 7.5]
# [6.5 6.5 6.5 7.5]
# [6.5 6.5 6.5 7.5]
# [6.  6.5 6.5 6.5]
# [6.  6.5 6.5 6.5]
# [6.  6.5 6.5 6.5]
# [6.  6.5 6.5 6.5]
# [6.5 7.  7.  7. ]
# [6.5 7.  7.  7. ]
# [6.5 7.  7.  7. ]
# [6.5 7.  7.  7. ]
# [6.  6.  6.5 6.5]
# [6.  6.  6.5 6.5]
# [6.  6.  6.5 6.5]
# [6.  6.  6.5 6.5]
# [6. 6. 7. 6.]
# [6. 6. 7. 6.]
# [6. 6. 7. 6.]
# [6. 6. 7. 6.]
# [6.  6.  6.5 0. ]
# [6.  6.  6.5 0. ]
# [6.  6.  6.5 0. ]
# [6.  6.  6.5 0. ]
# [6.  6.5 6.5 7.5]
# [6.  6.5 6.5 7.5]
# [6.  6.5 6.5 7.5]
# [6.  6.5 6.5 7.5]
# [6.5 6.5 6.5 6. ]
# [6.5 6.5 6.5 6. ]
# [6.5 6.5 6.5 6. ]
# [6.5 6.5 6.5 6. ]
# [6.  6.5 6.5 6. ]
# [6.  6.5 6.5 6. ]
# [6.  6.5 6.5 6. ]
# [6.  6.5 6.5 6. ]
# [6.5 6.5 7.5 6.5]
# [6.5 6.5 7.5 6.5]
# [6.5 6.5 7.5 6.5]
# [6.5 6.5 7.5 6.5]
# [6.  6.  6.5 6. ]
# [6.  6.  6.5 6. ]
# [6.  6.  6.5 6. ]
# [6.  6.  6.5 6. ]
# [6.  6.  6.5 6. ]
# [6.  6.  6.5 6. ]
# [6.  6.  6.5 6. ]
# [6.  6.  6.5 6. ]
# [6.  6.5 7.  0. ]
# [6.  6.5 7.  0. ]
# [6.  6.5 7.  0. ]
# [6.  6.5 7.  0. ]
# [6.5 6.5 7.  6.5]
# [6.5 6.5 7.  6.5]
# [6.5 6.5 7.  6.5]
# [6.5 6.5 7.  6.5]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4c99c590bc98> in <module>
# ----> 1 rose_best, classifica_best, classifica_q_best = main_model(N_campionati, struttura_rosa, team_names, teams, quotazioni, path_voti, N_squadre, valori_modificatore, fasce_modificatore, fasce_goal, formazioni)
#
# ~/Desktop/Fantacalcio/Utilities_fantapalla.py in main_model(n_campionati, struttura_rosa, team_names, teams, quotazioni, path, num_squadre, valori, fasce, fasce_goal, formazioni)
#     323     for i in range(n_campionati):
#     324         print('Campionato attuale:' f'{i+1}\r', end="")
# --> 325         classifica, rose, rose_id= simula_campionato(struttura_rosa, team_names, teams, quotazioni, path, num_squadre, valori, fasce, fasce_goal, formazioni)
#     326         quot_dict = all_quot_dict(struttura_rosa, quotazioni, num_squadre)
#     327         classifica_quot = assign_quot(rose_id, quot_dict, team_names)
#
# ~/Desktop/Fantacalcio/Utilities_fantapalla.py in simula_campionato(struttura_rosa, team_names, teams, quotazioni, path, num_squadre, valori, fasce, fasce_goal, formazioni)
#     303         voti_giornata = pd.read_excel(filename,sheet_name=0,skiprows=rows_to_skip)
#     304         fixtures = fixture_gen(teams)
# --> 305         dict_voti_giornata = all_grades_dict(struttura_rosa, quotazioni, voti_giornata, num_squadre)
#     306         voti_squadre = voti_max(rose, struttura_rosa, formazioni, dict_voti_giornata, teams, num_squadre, valori, fasce)
#     307         punti = pd.DataFrame.from_dict(points(fixtures, voti_squadre, fasce_goal),orient='index')
#
# ~/Desktop/Fantacalcio/Utilities_fantapalla.py in all_grades_dict(struttura_rosa, quotazioni, voti_giornata, num_squadre)
#     164             continue
#     165         for j in range(1,len(players['My Id'])+1):
# --> 166             if players['FC Id'][j] == np.float(voti_giornata['Cod.'][k]):
#     167                 #print(voti_giornata['Cod.'][k])
#     168                 temp_votes[j]=voti_giornata['Voto'][k]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4377         # use this, e.g. DatetimeIndex
#    4378         # Things like `Series._get_value` (via .at) pass the EA directly here.
# -> 4379         s = extract_array(series, extract_numpy=True)
#    4380         if isinstance(s, ExtensionArray):
#    4381             if is_scalar(key):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/construction.py in extract_array(obj, extract_numpy)
#     378     """
#     379     if isinstance(obj, (ABCIndexClass, ABCSeries)):
# --> 380         obj = obj.array
#     381
#     382     if extract_numpy and isinstance(obj, ABCPandasArray):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in array(self)
#     516     @property
#     517     def array(self) -> ExtensionArray:
# --> 518         return self._data._block.array_values()
#     519
#     520     def _internal_get_values(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in array_values(self)
#     221         The array that Series.array returns. Always an ExtensionArray.
#     222         """
# --> 223         return PandasArray(self.values)
#     224
#     225     def get_values(self, dtype=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py in __init__(self, values, copy)
#     151
#     152         self._ndarray = values
# --> 153         self._dtype = PandasDtype(values.dtype)
#     154
#     155     @classmethod
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py in __init__(self, dtype)
#      40     _metadata = ("_dtype",)
#      41
# ---> 42     def __init__(self, dtype):
#      43         dtype = np.dtype(dtype)
#      44         self._dtype = dtype
#
# KeyboardInterrupt:

# %%
classifica_best
# Out:
#         tot
# Team 1   42
# Team 2   50
# Team 3   57
# Team 4   66
# Team 5   53
# Team 6   11
# Team 7   39
# Team 8   60

# %%
rose_best
# Out:
#           Team 1            Team 2     Team 3          Team 4         Team 5  \
# 0        GOLLINI         DRAGOWSKI     CORDAZ           MERET      PAU LOPEZ
# 1     HANDANOVIC             MUSSO  STRAKOSHA          CRAGNO  DONNARUMMA G.
# 2       ROSSI F.         SKORUPSKI   CONSIGLI            SEPE       MONTIPO'
# 3          KJAER           BIRAGHI   DJIMSITI     LUIZ FELIPE        FARAONI
# 4      MUSACCHIO        MILENKOVIC       BANI         MANCINI   RODRIGUEZ R.
# 5        KOLAROV          N'KOULOU   SKRINIAR    HERNANDEZ T.       KUMBULLA
# 6     DI LORENZO         ROMAGNOLI      YOUNG      CEPPITELLI       CUADRADO
# 7        AUGELLO             GODIN   NUYTINCK       KOULIBALY        ANSALDI
# 8         ROMERO              RADU      TOLOI       MARIO RUI        BASTONI
# 9           IZZO          RRAHMANI    DE VRIJ            GLIK         GOSENS
# 10   BRUNO ALVES     PEZZELLA GER.    MANOLAS  STRYGER LARSEN     SPINAZZOLA
# 11      ZACCAGNI        MKHITARYAN  MIRANCHUK    LUIS ALBERTO         TONALI
# 12     BENTANCUR       BONAVENTURA    AMRABAT      KULUSEVSKI        PEREIRO
# 13  BERNARDESCHI            PULGAR     CHIESA         BENASSI          ELMAS
# 14         VIOLA         ZIELINSKI    DIAZ B.         RAMIREZ        PASALIC
# 15       LAZOVIC           PERISIC    LINETTY          NANDEZ        SORIANO
# 16       ERIKSEN          DJURICIC   POLITANO         FREULER        LAZZARI
# 17        KURTIC  MILINKOVIC-SAVIC      KUCKA        VERETOUT     CASTILLEJO
# 18        JANKTO              RUIZ     SOTTIL         DE ROON          SENSI
# 19        BARROW            CAPUTO      DZEKO         BELOTTI        MERTENS
# 20       INGLESE              SIMY    LASAGNA          MURIEL        OSIMHEN
# 21   MARTINEZ L.            CORREA   GERVINHO          LUKAKU      ZAPATA D.
# 22    GABBIADINI              ZAZA     ILICIC     IBRAHIMOVIC        CAICEDO
# 23         PEDRO           HIGUAIN      OKAKA         KOUAME'   QUAGLIARELLA
# 24   RAFAEL LEAO         BONAZZOLI      MILIK            BOGA       ORSOLINI
#
#          Team 6         Team 7          Team 8
# 0    SPORTIELLO         SIRIGU       SILVESTRI
# 1          ZOET          PERIN          AUDERO
# 2   CARNESECCHI       SZCZESNY          OSPINA
# 3       CACERES         IBANEZ           DIJKS
# 4      HATEBOER    BRUNO PERES      D'AMBROSIO
# 5        HAKIMI      CHIELLINI         YOSHIDA
# 6    MAKSIMOVIC       TOMIYASU        CRISCITO
# 7    FERRARI G.       PALOMINO     ALEX SANDRO
# 8      GAGLIOLO         LIROLA     DANILO LAR.
# 9        ACERBI        DARMIAN         DE LIGT
# 10      VOJVODA         COLLEY         BONUCCI
# 11         ZAJC  DOUGLAS COSTA           UNDER
# 12      DE PAUL     CALHANOGLU  PELLEGRINI LO.
# 13        GOMEZ         ARTHUR          RAMSEY
# 14        VERDI        ZANIOLO     MALINOVSKYI
# 15       RABIOT         BENALI       LOCATELLI
# 16     BROZOVIC        PEROTTI      NAINGGOLAN
# 17      DIAWARA    CASTROVILLI         KESSIE'
# 18      BARELLA            ROG           BARAK
# 19        REBIC        SANCHEZ          DYBALA
# 20      SIMEONE      PAVOLETTI        VLAHOVIC
# 21   JOAO PEDRO        INSIGNE         PETAGNA
# 22      CUTRONE    NESTOROVSKI       CORNELIUS
# 23      RONALDO    IAGO FALQUE          RIBERY
# 24     LAPADULA        BERARDI        IMMOBILE

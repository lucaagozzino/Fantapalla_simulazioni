# %%
#test github 2
import numpy as np
import pandas as pd
from Utilities_fantapalla import main_model, names, styling_rows, ruoli, FC_colors

# %%
quotazioni = pd.read_csv ('Quotazioni_Fantacalcio.csv')
# il file quotazioni contiene la lista dei giocatori direttamente da fantacalcio.it, che non ha i dati (in .gitignore)
# perfettamente aggiornati alcuni giocatori sono gia' fuori (tipo higuahin) o infortunati (tipo zaniolo), 
# quindi dobbiamo rimuovere a mano quelli che non ci interessano 
path_voti = 'Voti_giornate/'
rows_to_skip=[0,1,2,3,4]
# i voti sono quelli delle 38 giornate del campionato 2019/2020

# %%
# struttura della rosa [por, dif, cen, att]
struttura_rosa = np.array([3, 8, 8, 6])

# quali formazioni sono permesse
formazioni = {
    '352': [1, 3, 5, 2],
    '343': [1, 3, 4, 3],
    '442': [1, 4, 4, 2],
    '541': [1, 5, 4, 1],
    '532': [1, 5, 3, 2],
    '433': [1, 4, 3, 3]
    #aggiungere tutte le altre formazioni
}
fasce_goal = np.array([66,  70,  84,  88,  92,  96, 100])
fasce_modificatore = np.array([6. , 6.5, 7. , 7.5, 8. ])
valori_modificatore = np.array([1, 3, 5, 6, 8])

N_squadre = 8

# quanti campionati simulare
N_campionati = 2500

[teams, team_names] = names(N_squadre) # output ridondanti ma mi seccavo modificare il resto
roles =  ruoli(struttura_rosa)

# %%
rose_best, classifica_best, classifica_q_best = main_model(N_campionati, struttura_rosa, team_names, teams, quotazioni, path_voti, N_squadre, valori_modificatore, fasce_modificatore, fasce_goal, formazioni)
# Out:
# 100% (2500 of 2500) |###################| Elapsed Time: 13:54:42 Time: 13:54:42

# %%
classifica_q_best
# Out:
#             0
# Team 1  349.0
# Team 2  369.0
# Team 3  367.0
# Team 4  350.0
# Team 5  356.0
# Team 6  353.0
# Team 7  348.0
# Team 8  358.0

# %%
rose_best
# Out:
#            Team 1          Team 2         Team 3       Team 4        Team 5  \
# 0   DONNARUMMA G.        SZCZESNY       ROSSI F.        MUSSO    HANDANOVIC
# 1       PAU LOPEZ       SILVESTRI           SEPE   SPORTIELLO          ZOET
# 2       STRAKOSHA     CARNESECCHI      SKORUPSKI       SIRIGU     DRAGOWSKI
# 3        SKRINIAR         BASTONI        DE LIGT       ACERBI    FERRARI G.
# 4         CACERES          COLLEY      MARIO RUI  BRUNO ALVES  HERNANDEZ T.
# 5           GODIN  STRYGER LARSEN    LUIZ FELIPE   CEPPITELLI     KOULIBALY
# 6       ROMAGNOLI      MAKSIMOVIC      MUSACCHIO        TOLOI      PALOMINO
# 7      SPINAZZOLA        CRISCITO       NUYTINCK       HAKIMI      RRAHMANI
# 8            IZZO       CHIELLINI  PEZZELLA GER.        KJAER    DI LORENZO
# 9         FARAONI         BONUCCI          DIJKS  BRUNO PERES       BIRAGHI
# 10        DE VRIJ        N'KOULOU    DANILO LAR.   D'AMBROSIO        IBANEZ
# 11        DE PAUL            ZAJC         SOTTIL       ARTHUR  LUIS ALBERTO
# 12        PERISIC         PEROTTI    MALINOVSKYI      PEREIRO        JANKTO
# 13        LINETTY          PULGAR         RAMSEY       RABIOT      VERETOUT
# 14        BARELLA     CASTROVILLI        ERIKSEN   CALHANOGLU       LAZZARI
# 15          BARAK      CASTILLEJO            ROG      AMRABAT       FREULER
# 16        SORIANO           VIOLA        DE ROON      PASALIC   BONAVENTURA
# 17        BENASSI         KESSIE'     MKHITARYAN        VERDI      ZACCAGNI
# 18        DIAWARA       BENTANCUR          KUCKA    MIRANCHUK       DIAZ B.
# 19    RAFAEL LEAO          CORREA         MURIEL       LUKAKU     ZAPATA D.
# 20        MERTENS       PAVOLETTI    IBRAHIMOVIC         SIMY     CORNELIUS
# 21    MARTINEZ L.      JOAO PEDRO        RONALDO      HIGUAIN   IAGO FALQUE
# 22       LAPADULA        IMMOBILE        SANCHEZ       RIBERY       INSIGNE
# 23        SIMEONE           DZEKO        PETAGNA     ORSOLINI       INGLESE
# 24       VLAHOVIC         KOUAME'          MILIK         ZAZA     BONAZZOLI
#
#            Team 6            Team 7        Team 8
# 0           MERET             PERIN       GOLLINI
# 1        MONTIPO'            CORDAZ        CRAGNO
# 2        CONSIGLI            OSPINA        AUDERO
# 3        CUADRADO           MANCINI        ROMERO
# 4        GAGLIOLO        MILENKOVIC        GOSENS
# 5         VOJVODA           KOLAROV          GLIK
# 6         AUGELLO          KUMBULLA   ALEX SANDRO
# 7         MANOLAS              RADU  RODRIGUEZ R.
# 8           YOUNG          HATEBOER       YOSHIDA
# 9         DARMIAN            LIROLA      TOMIYASU
# 10       DJIMSITI              BANI       ANSALDI
# 11         BENALI          DJURICIC         GOMEZ
# 12         NANDEZ          BROZOVIC       ZANIOLO
# 13          SENSI    PELLEGRINI LO.         ELMAS
# 14          UNDER           LAZOVIC     ZIELINSKI
# 15  DOUGLAS COSTA              RUIZ        KURTIC
# 16         CHIESA            TONALI    KULUSEVSKI
# 17        RAMIREZ  MILINKOVIC-SAVIC  BERNARDESCHI
# 18      LOCATELLI        NAINGGOLAN      POLITANO
# 19         ILICIC            BARROW       CAICEDO
# 20           BOGA           CUTRONE       BERARDI
# 21    NESTOROVSKI        GABBIADINI  QUAGLIARELLA
# 22         DYBALA           BELOTTI      GERVINHO
# 23          PEDRO           LASAGNA         OKAKA
# 24         CAPUTO             REBIC       OSIMHEN

# %%
#rose_best.to_pickle('rose_best.pkl')
rose_best_pickle = pd.read_pickle('rose_best.pkl')

# %%
FC_colors(rose_best, struttura_rosa)
# Out:
# <style  type="text/css" >
#     #T_5da463a4_f9bf_11ea_b276_acde48001122row0_col0 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row0_col1 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row0_col2 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row0_col3 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row0_col4 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row0_col5 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row0_col6 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row0_col7 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row1_col0 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row1_col1 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row1_col2 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row1_col3 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row1_col4 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row1_col5 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row1_col6 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row1_col7 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row2_col0 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row2_col1 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row2_col2 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row2_col3 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row2_col4 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row2_col5 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row2_col6 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row2_col7 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row3_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row3_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row3_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row3_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row3_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row3_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row3_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row3_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row4_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row4_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row4_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row4_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row4_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row4_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row4_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row4_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row5_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row5_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row5_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row5_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row5_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row5_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row5_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row5_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row6_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row6_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row6_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row6_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row6_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row6_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row6_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_5da463a4_f9bf_11ea_b276_acde48001122row6_col7 {
#             background-color:

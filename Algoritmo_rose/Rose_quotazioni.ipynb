# %%
import pandas as pd
import numpy as np
from Utilities_fantapalla import *
from joblib import Parallel, delayed
import progressbar
import time
#quotazioni = pd.read_csv ('SCARICA NUOVO FILE E TOGLI I MIGLIORI (8 PORTIERI E 16 PER GLI ALTRI RUOLI).csv')
quotazioni = pd.read_csv('Quotazioni_Fantacalcio_reduced(5-Oct).csv')

# %%
portieri = np.array([2, 0, 0, 0])
resto = np.array([0, 6, 6, 4])
num_squadre = 8
teams, team_names = names(num_squadre)
N_cores = 8

# %%
rosa_portieri = genera_rose(portieri, num_squadre)

# %%
quot_dict_portieri = all_quot_dict(portieri, quotazioni, num_squadre)
quot_dict_resto = all_quot_dict(resto, quotazioni, num_squadre)

# %%
def spread(rosa, team_names, quot_dict):
    spread = np.float(np.max(assign_quot(rosa, quot_dict, team_names))-np.min(assign_quot(rosa, quot_dict, team_names)))
    return spread

# %%
def find_rosa(struttura_rosa, num_squadre, quotazioni, team_names, iterations = 100):
    rosa = genera_rose(struttura_rosa, num_squadre)
    quot_dict = all_quot_dict(struttura_rosa, quotazioni, num_squadre)
    rose_generate = Parallel(n_jobs = N_cores)(delayed(genera_rose)(struttura_rosa, num_squadre) for i in progressbar.progressbar(range(iterations)))
    all_spread = Parallel(n_jobs = N_cores)(delayed(spread)(rosa, team_names, quot_dict) for rosa in progressbar.progressbar(rose_generate))
    min_ind = np.argmin(all_spread)
    output = pd.DataFrame(data = rose_generate[min_ind], columns = team_names)
    return output

# %%
rosa_best_portieri = find_rosa(portieri, num_squadre, quotazioni, team_names, iterations = 5000000)

# %%
assign_quot(rosa_best_portieri, quot_dict_portieri, team_names)
# Out:
#            0
# Team 1  13.0
# Team 2  13.0
# Team 3  14.0
# Team 4  16.0
# Team 5  15.0
# Team 6  16.0
# Team 7  14.0
# Team 8  16.0

# %%
rosa_best_resto = find_rosa(resto, num_squadre, quotazioni, team_names, iterations = 50000000)

# %%
assign_quot(rosa_best_resto, quot_dict_resto, team_names)
# Out:
#             0
# Team 1  191.0
# Team 2  192.0
# Team 3  192.0
# Team 4  190.0
# Team 5  191.0
# Team 6  190.0
# Team 7  190.0
# Team 8  190.0

# %%
nomi_portieri = id_toName(portieri, quotazioni, rosa_best_portieri, num_squadre, team_names)
nomi_resto = id_toName(resto, quotazioni, rosa_best_resto, num_squadre, team_names)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FRANCESCO'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-2fda5d2b42a0> in <module>
# ----> 1 nomi_portieri = id_toName(portieri, quotazioni, rosa_best_portieri, num_squadre, team_names)
#       2 nomi_resto = id_toName(resto, quotazioni, rosa_best_resto, num_squadre, team_names)
#
# ~/Desktop/Fantacalcio/Utilities_fantapalla.py in id_toName(struttura_rosa, quotazioni, rose, num_squadre, team_names)
#     259     for team_name in team_names:
#     260         temp_teams = []
# --> 261         for Myid in rose[team_name]:
#     262              temp_teams.append(topPlayers['Nome'][Myid])
#     263         rose_nomi[team_name] = temp_teams
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FRANCESCO'

# %%
struttura_parziale = portieri+resto
nomi_resto.index =  list(range(3,19))
rosa_parziale = pd.concat([nomi_portieri, nomi_resto], axis = 0)
#rosa_parziale.to_pickle('rose_parziali_UFFICIALI.pkl')
FC_colors(rosa_parziale, struttura_parziale)
# Out:
# <style  type="text/css" >
#     #T_583fc6e8_080a_11eb_9fd0_acde48001122row0_col0 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row0_col1 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row0_col2 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row0_col3 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row0_col4 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row0_col5 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row0_col6 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row0_col7 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row1_col0 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row1_col1 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row1_col2 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row1_col3 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row1_col4 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row1_col5 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row1_col6 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row1_col7 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row2_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row2_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row2_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row2_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row2_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row2_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row2_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row2_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row3_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row3_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row3_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row3_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row3_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row3_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row3_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row3_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row4_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row4_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row4_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row4_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row4_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row4_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row4_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row4_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row5_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row5_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row5_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row5_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row5_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row5_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row5_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row5_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row6_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row6_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row6_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row6_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row6_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row6_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row6_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_583fc6e8_080a_11eb_9fd0_acde48001122row6_col7 {
#             background-color:  rgba(46

# %%
rosa_parzial_pickle = pd.read_pickle('rose_parziali_UFFICIALI.pkl')
rosa_assegnata = FC_colors(rosa_parzial_pickle, struttura_parziale)

# %% [markdown]
# # Ora determiniamo gli accoppiamenti sulla base delle preferenze

# %%
import itertools
import random

# %%
team_list = list(range(8)) #lista numerica delle squadre
f = ['LUCA', 'PIETRO', 'ENZO', 'NANNI', 'MUSCIOTTO', 'EMILIANO', 'MARIO', 'FRANCESCO']

# %%
permutations = list(itertools.permutations(team_list)) #generazione di tutte le possibili peermutazioni
"""
Ogni giocatore scelto contribuisce con un fattore 1000 al peso, quindi se per esempio L ha scelto 2 giocatori dalla
prima squadra e 1 dalla seconda il vettore dei pesi sara':
[2000, 1000, 0, 0, 0, 0, 0, 0]

"""
# Out:
# "\nOgni giocatore scelto contribuisce con un fattore 1000 al peso, quindi se per esempio L ha scelto 2 giocatori dalla\nprima squadra e 1 dalla seconda il vettore dei pesi sara':\n[2000, 1000, 0, 0, 0, 0, 0, 0]\n\n"

# %%
#matrice delle preferenze (ESEMPIO)
preferences = np.array([
    [1000, 0,    1000, 0,    0,    0,    0,    1000], #LUCA
    [2000, 1000, 0,    0,    0,    0,    0,    0], #PIETRO
    [0,    1000, 2000, 0,    0,    0,    0,    0], #ENZO
    [0,    0,    0,    1000, 1000, 1000, 0,    0], #NANNI
    [1000, 0,    0,    1000, 0,    1000, 0,    0], #MUSCIOTTO
    [0,    1000, 0,    1000, 0,    1000, 0,    0], #EMILIANO
    [1000, 0,    0,    0,    1000, 0,    1000, 0], #MARIO
    [2000, 1000, 0,    0,    0,    0,    0,    0], #FRANCESCO
])

# %%
#assegnazione di una probabilita' ad ogni permutazione sulla base delle preferenze
prob = np.zeros((len(permutations)))
for j in range(len(permutations)):
    prob[j] = 1e200*sum(preferences[i][permutations[j][i]] for i in range(8))

# %%
prob_norm = prob/np.sum(prob) #normalizzo la probabilita'
N = 100 #numero di permutazioni con peso piu' alto
ind = np.argpartition(prob_norm, -N)[-N:]
prob2 = np.zeros(len(prob_norm))
prob2[ind] = prob_norm[ind]/np.max(prob_norm)

# %%
# una permutazione viene scelta a caso usando la distribuzione di probabilita' assegnata
assignments = random.choices(permutations, weights = prob2, k=1)
dic = {}
for k in progressbar.progressbar(range(len(assignments[0]))):
    dic[f[k]] = ['Team '+str(assignments[0][k]+1)]
    time.sleep(3.)
pd.DataFrame(data=dic)
# Out:
# 100% (8 of 8) |##########################| Elapsed Time: 0:00:24 Time:  0:00:24
#      LUCA  PIETRO    ENZO   NANNI MUSCIOTTO EMILIANO   MARIO FRANCESCO
# 0  Team 8  Team 4  Team 3  Team 7    Team 6   Team 2  Team 5    Team 1

# %%
rosa_assegnata = rosa_parzial_pickle
rosa_assegnata.columns = team_names

# %%
team_names = ['FRANCESCO', 'EMILIANO', 'ENZO', 'PIETRO', 'MARIO', 'MUSCIOTTO', 'NANNI', 'LUCA']

# %%
FC_colors(rosa_assegnata,struttura_parziale)
# Out:
# <style  type="text/css" >
#     #T_22dbd52c_0815_11eb_9fd0_acde48001122row0_col0 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row0_col1 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row0_col2 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row0_col3 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row0_col4 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row0_col5 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row0_col6 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row0_col7 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row1_col0 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row1_col1 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row1_col2 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row1_col3 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row1_col4 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row1_col5 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row1_col6 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row1_col7 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row2_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row2_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row2_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row2_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row2_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row2_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row2_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row2_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row3_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row3_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row3_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row3_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row3_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row3_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row3_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row3_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row4_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row4_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row4_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row4_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row4_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row4_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row4_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row4_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row5_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row5_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row5_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row5_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row5_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row5_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row5_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row5_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row6_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row6_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row6_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row6_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row6_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row6_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row6_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_22dbd52c_0815_11eb_9fd0_acde48001122row6_col7 {
#             background-color:  rgba(46

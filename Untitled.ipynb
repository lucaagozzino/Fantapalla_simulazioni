# %%
import numpy as np
import pandas as pd

# %%
#Importing libraries
import pandas as pd
df = pd.DataFrame(np.random.rand(25,8))
df.head()
# We want to color cell at <3,2>. Coloring the background red, and text color Violet
# Custom function to color the desired cell
def styling_specific_cell(x,row_idx,col_idx):
    color = 'background-color: red; color: violet'
    df_styler = pd.DataFrame('', index=x.index, columns=x.columns)
    df_styler.iloc[row_idx, col_idx] = color
    return df_styler
idx_r = 3   # Row index of cell to color
idx_c = 2   # Column index of cell to color 
# Pass the row and column index as kwargs
df.style.apply(styling_specific_cell, row_idx = idx_r, col_idx = idx_c, axis = None)  # Axis set to None to work on entire dataframe
# Out:
# <style  type="text/css" >
#     #T_ca16994e_f753_11ea_aa43_acde48001122row3_col2 {
#             background-color:  red;
#              color:  violet;
#         }</style><table id="T_ca16994e_f753_11ea_aa43_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca16994e_f753_11ea_aa43_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ca16994e_f753_11ea_aa43_acde48001122row0_col0" class="data row0 col0" >0.945504</td>
# ...

# %%
def styling_specific_cell(x,row_idx,col_idx):
    color = 'background-color: red; color: violet'
    df_styler = pd.DataFrame('', index=x.index, columns=x.columns)
    df_styler.iloc[row_idx, col_idx] = color
    return df_styler

# %%
struttura_rosa = np.array([3, 8, 8, 6])
def styling_rows(x, struttura):
    [P,D,C,A] = struttura
    color_P = 'background-color: orange; color: black'
    color_D = 'background-color: darkseagreen; color: black'
    color_C = 'background-color: cornflowerblue; color: black'
    color_A = 'background-color: tomato; color: black'
    df_styler = pd.DataFrame('', index=x.index, columns=x.columns)
    col_idx = range(df_styler.shape[1])
    row_idx_P = P
    row_idx_D = D
    for idx in range(P):
        df_styler.iloc[idx, col_idx] = color_P
    for idx in range(P,P+D):
        df_styler.iloc[idx, col_idx] = color_D
    for idx in range(P+D,P+D+C):
        df_styler.iloc[idx, col_idx] = color_C
    for idx in range(P+D+C,P+D+C+A):
        df_styler.iloc[idx, col_idx] = color_A
    return df_styler

# %%
df.style.apply(styling_rows, struttura = struttura_rosa, axis = None)  # Axis set to None to work on entire dataframe
# Out:
# <style  type="text/css" >
#     #T_e4abb7be_f756_11ea_aa43_acde48001122row0_col0 {
#             background-color:  orange;
#              color:  black;
#         }    #T_e4abb7be_f756_11ea_aa43_acde48001122row0_col1 {
#             background-color:  orange;
#              color:  black;
#         }    #T_e4abb7be_f756_11ea_aa43_acde48001122row0_col2 {
#             background-color:  orange;
#              color:  black;
#         }    #T_e4abb7be_f756_11ea_aa43_acde48001122row0_col3 {
#             background-color:  orange;
#              color:  black;
#         }    #T_e4abb7be_f756_11ea_aa43_acde48001122row0_col4 {
#             background-color:  orange;
#              color:  black;
#         }    #T_e4abb7be_f756_11ea_aa43_acde48001122row0_col5 {
#             background-color:  orange;
#              color:  black;
#         }    #T_e4abb7be_f756_11ea_aa43_acde48001122row0_col6 {
#             background-color:  orange;
#              color:  black;
# ...

# %%
np.arange(3,5)
# Out:
# array([3, 4])

# %%
#test github 2
import numpy as np
import pandas as pd
from Utilities_fantapalla import main_model, names

quotazioni = pd.read_csv ('Quotazioni_Fantacalcio.csv')
# il file quotazioni contiene la lista dei giocatori direttamente da fantacalcio.it, che non ha i dati (in .gitignore)
# perfettamente aggiornati alcuni giocatori sono gia' fuori (tipo higuahin) o infortunati (tipo zaniolo), 
# quindi dobbiamo rimuovere a mano quelli che non ci interessano 
path_voti = 'Voti_giornate/'
rows_to_skip=[0,1,2,3,4]
# i voti sono quelli delle 38 giornate del campionato 2019/2020

# %%
# struttura della rosa [por, dif, cen, att]
struttura_rosa = np.array([3, 8, 8, 6])

# quali formazioni sono permesse
formazioni = {
    '352': [1, 3, 5, 2],
    '343': [1, 3, 4, 3],
    '442': [1, 4, 4, 2],
    '541': [1, 5, 4, 1],
    '532': [1, 5, 3, 2],
    '433': [1, 4, 3, 3]
    #aggiungere tutte le altre formazioni
}
fasce_goal = np.array([66,  70,  84,  88,  92,  96, 100])
fasce_modificatore = np.array([6. , 6.5, 7. , 7.5, 8. ])
valori_modificatore = np.array([1, 3, 5, 6, 8])

N_squadre = 8

# quanti campionati simulare
N_campionati = 800

[teams, team_names] = names(N_squadre) # output ridondanti ma mi seccavo modificare il resto

# %%
rose_best, classifica_best, classifica_q_best = main_model(N_campionati, struttura_rosa, team_names, teams, quotazioni, path_voti, N_squadre, valori_modificatore, fasce_modificatore, fasce_goal, formazioni)
# Out:
# 100% |########################################################################|

# %%
classifica_best
# Out:
#         tot
# Team 1   34
# Team 2   51
# Team 3   55
# Team 4   52
# Team 5   50
# Team 6   35
# Team 7   36
# Team 8   37

# %%
rose_best
# Out:
#          Team 1         Team 2       Team 3         Team 4        Team 5  \
# 0        AUDERO  DONNARUMMA G.      GOLLINI          MUSSO        CRAGNO
# 1         PERIN      SILVESTRI    DRAGOWSKI           SEPE      MONTIPO'
# 2        SIRIGU     SPORTIELLO    SKORUPSKI      PAU LOPEZ    HANDANOVIC
# 3      CRISCITO         GOSENS      VOJVODA        ANSALDI  HERNANDEZ T.
# 4   LUIZ FELIPE   RODRIGUEZ R.    MUSACCHIO          DIJKS    CEPPITELLI
# 5      PALOMINO        BASTONI      BONUCCI          TOLOI   BRUNO PERES
# 6       DE LIGT        CACERES    CHIELLINI           RADU       BIRAGHI
# 7        IBANEZ      KOULIBALY     CUADRADO       TOMIYASU    DI LORENZO
# 8    D'AMBROSIO          GODIN     NUYTINCK      ROMAGNOLI       DARMIAN
# 9         KJAER     MILENKOVIC  BRUNO ALVES        FARAONI   DANILO LAR.
# 10      KOLAROV       KUMBULLA     RRAHMANI           BANI       MANCINI
# 11       PULGAR   BERNARDESCHI       NANDEZ         KURTIC       DIAWARA
# 12      LAZZARI      LOCATELLI  CASTROVILLI  DOUGLAS COSTA       RAMIREZ
# 13       SOTTIL     CASTILLEJO       BENALI        DIAZ B.    CALHANOGLU
# 14         ZAJC         JANKTO      PASALIC        DE ROON       LAZOVIC
# 15      DE PAUL        PEREIRO    MIRANCHUK        PEROTTI        RABIOT
# 16      ZANIOLO       VERETOUT      SORIANO          GOMEZ  LUIS ALBERTO
# 17       TONALI           RUIZ     POLITANO         ARTHUR         ELMAS
# 18        VIOLA          SENSI     ZACCAGNI          KUCKA    KULUSEVSKI
# 19        MILIK        HIGUAIN        REBIC          DZEKO        ILICIC
# 20         ZAZA    IAGO FALQUE  RAFAEL LEAO        BERARDI     CORNELIUS
# 21     VLAHOVIC      ZAPATA D.  IBRAHIMOVIC         MURIEL        CORREA
# 22       LUKAKU     GABBIADINI        OKAKA        CAICEDO       CUTRONE
# 23      SANCHEZ        PETAGNA       RIBERY        BELOTTI      GERVINHO
# 24    PAVOLETTI        LASAGNA      MERTENS        INSIGNE      LAPADULA
#
#            Team 6          Team 7            Team 8
# 0            ZOET        ROSSI F.          CONSIGLI
# 1       STRAKOSHA     CARNESECCHI            OSPINA
# 2          CORDAZ        SZCZESNY             MERET
# 3          ACERBI      MAKSIMOVIC          N'KOULOU
# 4         MANOLAS      SPINAZZOLA          HATEBOER
# 5   PEZZELLA GER.            GLIK           YOSHIDA
# 6       MARIO RUI     ALEX SANDRO          DJIMSITI
# 7      FERRARI G.           YOUNG    STRYGER LARSEN
# 8          HAKIMI        SKRINIAR           DE VRIJ
# 9        GAGLIOLO            IZZO           AUGELLO
# 10         COLLEY          LIROLA            ROMERO
# 11     NAINGGOLAN         LINETTY          DJURICIC
# 12        BARELLA           BARAK       MALINOVSKYI
# 13        KESSIE'         BENASSI       BONAVENTURA
# 14         RAMSEY       BENTANCUR             VERDI
# 15        ERIKSEN         AMRABAT         ZIELINSKI
# 16          UNDER  PELLEGRINI LO.  MILINKOVIC-SAVIC
# 17     MKHITARYAN        BROZOVIC            CHIESA
# 18        FREULER             ROG           PERISIC
# 19          PEDRO        IMMOBILE       MARTINEZ L.
# 20   QUAGLIARELLA            BOGA          ORSOLINI
# 21     JOAO PEDRO         OSIMHEN           INGLESE
# 22         DYBALA         KOUAME'            CAPUTO
# 23           SIMY         RONALDO            BARROW
# 24    NESTOROVSKI         SIMEONE         BONAZZOLI

# %%
rose_best.to_pickle('rose_best.pkl')

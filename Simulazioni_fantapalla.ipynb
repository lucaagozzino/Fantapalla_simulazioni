# %%
import numpy as np
import pandas as pd
from Utilities_fantapalla import main_model, names

quotazioni = pd.read_csv ('Quotazioni_Fantacalcio.csv')
# il file quotazioni contiene la lista dei giocatori direttamente da fantacalcio.it, che non ha i dati 
# perfettamente aggiornati alcuni giocatori sono gia' fuori (tipo higuahin) o infortunati (tipo zaniolo), 
# quindi dobbiamo rimuovere a mano quelli che non ci interessano 
path_voti = 'Voti_giornate/'
rows_to_skip=[0,1,2,3,4]
# i voti sono quelli delle 38 giornate del campionato 2019/2020

# %%
# struttura della rosa [por, dif, cen, att]
struttura_rosa = np.array([3, 8, 8, 6])

# quali formazioni sono permesse
formazioni = {
    '352': [1, 3, 5, 2],
    '343': [1, 3, 4, 3],
    '442': [1, 4, 4, 2],
    '541': [1, 5, 4, 1],
    '532': [1, 5, 3, 2],
    '433': [1, 4, 3, 3]
    #aggiungere tutte le altre formazioni
}
fasce_goal = np.array([66,  70,  84,  88,  92,  96, 100])
fasce_modificatore = np.array([6. , 6.5, 7. , 7.5, 8. ])
valori_modificatore = np.array([1, 3, 5, 6, 8])

N_squadre = 8

[teams, team_names] = names(N_squadre)

# %%
rose_best, classifica_best, classifica_q_best = main_model(200, struttura_rosa, team_names, teams, quotazioni, path_voti, N_squadre, valori_modificatore, fasce_modificatore, fasce_goal, formazioni)
# Out:
# Campionato attuale:200

# %%
classifica_best
# Out:
#         tot
# Team 1   50
# Team 2   41
# Team 3   48
# Team 4   46
# Team 5   47
# Team 6   49
# Team 7   38
# Team 8   32

# %%
rose_best
# Out:
#           Team 1       Team 2          Team 3          Team 4        Team 5  \
# 0      STRAKOSHA      GOLLINI     CARNESECCHI       DRAGOWSKI         PERIN
# 1       CONSIGLI       AUDERO           MUSSO       PAU LOPEZ     SILVESTRI
# 2       ROSSI F.         ZOET        MONTIPO'   DONNARUMMA G.    SPORTIELLO
# 3   RODRIGUEZ R.         GLIK        TOMIYASU     BRUNO ALVES      KUMBULLA
# 4         GOSENS   MAKSIMOVIC  STRYGER LARSEN         KOLAROV      RRAHMANI
# 5      MARIO RUI      CACERES           TOLOI     DANILO LAR.       MANOLAS
# 6        FARAONI   SPINAZZOLA        CRISCITO           KJAER     CHIELLINI
# 7           IZZO       LIROLA        NUYTINCK     LUIZ FELIPE      GAGLIOLO
# 8     DI LORENZO       COLLEY            BANI      FERRARI G.       VOJVODA
# 9        DARMIAN   MILENKOVIC     BRUNO PERES     ALEX SANDRO      PALOMINO
# 10      SKRINIAR        DIJKS         ANSALDI         BONUCCI       AUGELLO
# 11        NANDEZ       CHIESA         PEROTTI          BENALI  LUIS ALBERTO
# 12        SOTTIL          ROG         AMRABAT          RAMSEY     LOCATELLI
# 13       DE PAUL      LAZZARI        ZACCAGNI           KUCKA       DIAWARA
# 14       DE ROON        BARAK           UNDER     MALINOVSKYI         ELMAS
# 15       DIAZ B.       JANKTO       BENTANCUR     BONAVENTURA    KULUSEVSKI
# 16        RABIOT     BROZOVIC          KURTIC          TONALI       KESSIE'
# 17       SORIANO         RUIZ        POLITANO         PERISIC       ZANIOLO
# 18    MKHITARYAN        VERDI           GOMEZ  PELLEGRINI LO.       PASALIC
# 19        MURIEL   GABBIADINI         SANCHEZ          CORREA      LAPADULA
# 20       SIMEONE       CAPUTO      JOAO PEDRO     IBRAHIMOVIC         PEDRO
# 21       KOUAME'    ZAPATA D.         CUTRONE         HIGUAIN         OKAKA
# 22       INGLESE        REBIC          ILICIC       CORNELIUS        LUKAKU
# 23      IMMOBILE      BELOTTI       BONAZZOLI         OSIMHEN       BERARDI
# 24         MILIK  IAGO FALQUE         RONALDO         MERTENS      ORSOLINI
#
#               Team 6         Team 7       Team 8
# 0             SIRIGU         OSPINA       CORDAZ
# 1          SKORUPSKI           SEPE       CRAGNO
# 2              MERET       SZCZESNY   HANDANOVIC
# 3             HAKIMI     CEPPITELLI        YOUNG
# 4         D'AMBROSIO           RADU    ROMAGNOLI
# 5             ROMERO         ACERBI      BIRAGHI
# 6            BASTONI  PEZZELLA GER.     CUADRADO
# 7          KOULIBALY         IBANEZ      DE VRIJ
# 8           DJIMSITI       HATEBOER    MUSACCHIO
# 9           N'KOULOU        MANCINI        GODIN
# 10      HERNANDEZ T.        DE LIGT      YOSHIDA
# 11              ZAJC        FREULER      ERIKSEN
# 12        CALHANOGLU       DJURICIC      LAZOVIC
# 13  MILINKOVIC-SAVIC        BARELLA        VIOLA
# 14        CASTILLEJO   BERNARDESCHI   NAINGGOLAN
# 15         ZIELINSKI  DOUGLAS COSTA       ARTHUR
# 16          VERETOUT         PULGAR        SENSI
# 17       CASTROVILLI        RAMIREZ      PEREIRO
# 18           LINETTY      MIRANCHUK      BENASSI
# 19           CAICEDO         BARROW     GERVINHO
# 20           LASAGNA       VLAHOVIC  RAFAEL LEAO
# 21         PAVOLETTI        PETAGNA         SIMY
# 22             DZEKO   QUAGLIARELLA  NESTOROVSKI
# 23              ZAZA           BOGA      INSIGNE
# 24            RIBERY    MARTINEZ L.       DYBALA

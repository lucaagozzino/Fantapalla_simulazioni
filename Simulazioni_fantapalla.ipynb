# %%
import numpy as np
import pandas as pd
from Utilities_fantapalla import main_model, names

quotazioni = pd.read_csv ('Quotazioni_Fantacalcio.csv')

# %%
struttura_rosa = np.array([3, 8, 8, 6])
#this must contain all the allowed schemes
352 - 343 - 451 - 442 - 433 - 532 - 541
formazioni = {
    '352': [1, 3, 5, 2],
    '343': [1, 3, 4, 3],
    '442': [1, 4, 4, 2],
    '541': [1, 5, 4, 1],
    '532': [1, 5, 3, 2],
    '433': [1, 4, 3, 3]
    #aggiungere tutte le altre formazioni
}
fasce_goal = np.array([66,  70,  84,  88,  92,  96, 100])
fasce_modificatore = np.array([6. , 6.5, 7. , 7.5, 8. ])
valori_modificatore = np.array([1, 3, 5, 6, 8])
rows_to_skip=[0,1,2,3,4]

N_squadre = 10

[teams, team_names] = names(N_squadre)

# %%
rose_best, classifica_best, classifica_q_best = main_model(1, struttura_rosa, team_names, teams, quotazioni, num_squadre = N_squadre)

# %%
rose_best
# Out:
#          Team 1        Team 2         Team 3        Team 4         Team 5  \
# 0          ZOET        CORDAZ  DONNARUMMA G.    HANDANOVIC         CRAGNO
# 1      SZCZESNY     STRAKOSHA      DRAGOWSKI         MERET      PAU LOPEZ
# 2        OSPINA       GOLLINI          MUSSO      MONTIPO'    CARNESECCHI
# 3       KOLAROV      CRISCITO        DARMIAN       CACERES           GLIK
# 4          RADU      KUMBULLA      MARIO RUI        COLLEY       GAGLIOLO
# 5        ACERBI       VOJVODA         ROMERO         YOUNG        AUGELLO
# 6    MAKSIMOVIC   BRUNO ALVES        BONUCCI       YOSHIDA     FERRARI G.
# 7     ROMAGNOLI   BRUNO PERES         GOSENS  RODRIGUEZ R.  PEZZELLA GER.
# 8    DI LORENZO    CEPPITELLI           IZZO       FARAONI       RRAHMANI
# 9     KOULIBALY        HAKIMI          TOLOI       BASTONI     D'AMBROSIO
# 10    MUSACCHIO     CHIELLINI       NUYTINCK  HERNANDEZ T.        MANOLAS
# 11         ZAJC         GOMEZ         RAMSEY      POLITANO          VIOLA
# 12        UNDER       ZANIOLO         KURTIC         VERDI      BENTANCUR
# 13      PASALIC    MKHITARYAN     CASTILLEJO    CALHANOGLU        KESSIE'
# 14     BROZOVIC       DIAWARA          BARAK   BONAVENTURA         SOTTIL
# 15      PEROTTI       BENASSI        PEREIRO        ARTHUR        AMRABAT
# 16      LAZOVIC       ERIKSEN         CHIESA       LINETTY     NAINGGOLAN
# 17    MIRANCHUK  BERNARDESCHI      ZIELINSKI       DE PAUL      LOCATELLI
# 18      DE ROON         KUCKA            ROG         SENSI         TONALI
# 19       LUKAKU      IMMOBILE        OSIMHEN      LAPADULA       ORSOLINI
# 20       RIBERY       CAICEDO         ILICIC      GERVINHO         CAPUTO
# 21  NESTOROVSKI   RAFAEL LEAO        BELOTTI     BONAZZOLI         BARROW
# 22       MURIEL  QUAGLIARELLA        INGLESE   MARTINEZ L.        PETAGNA
# 23      HIGUAIN       RONALDO      CORNELIUS     PAVOLETTI           SIMY
# 24      SANCHEZ         MILIK        LASAGNA       INSIGNE    IAGO FALQUE
#
#             Team 6          Team 7            Team 8
# 0       SPORTIELLO            SEPE         SKORUPSKI
# 1            PERIN       SILVESTRI            SIRIGU
# 2           AUDERO        CONSIGLI          ROSSI F.
# 3           IBANEZ         DE LIGT           BIRAGHI
# 4   STRYGER LARSEN         MANCINI       ALEX SANDRO
# 5         N'KOULOU        HATEBOER          DJIMSITI
# 6         CUADRADO        PALOMINO             GODIN
# 7            DIJKS        SKRINIAR             KJAER
# 8         TOMIYASU     LUIZ FELIPE           ANSALDI
# 9       MILENKOVIC      SPINAZZOLA            LIROLA
# 10     DANILO LAR.         DE VRIJ              BANI
# 11    LUIS ALBERTO  PELLEGRINI LO.       CASTROVILLI
# 12        DJURICIC          NANDEZ           RAMIREZ
# 13         LAZZARI         PERISIC           SORIANO
# 14          PULGAR         DIAZ B.     DOUGLAS COSTA
# 15          RABIOT     MALINOVSKYI            BENALI
# 16        VERETOUT        ZACCAGNI  MILINKOVIC-SAVIC
# 17          JANKTO           ELMAS              RUIZ
# 18         FREULER         BARELLA        KULUSEVSKI
# 19         MERTENS       ZAPATA D.           CUTRONE
# 20           PEDRO      GABBIADINI           BERARDI
# 21     IBRAHIMOVIC        VLAHOVIC              BOGA
# 22           REBIC          CORREA             DZEKO
# 23           OKAKA         KOUAME'            DYBALA
# 24            ZAZA         SIMEONE        JOAO PEDRO

# %%
#test github 2
import numpy as np
import pandas as pd
from Utilities_fantapalla import main_model, names

quotazioni = pd.read_csv ('Quotazioni_Fantacalcio.csv')
# il file quotazioni contiene la lista dei giocatori direttamente da fantacalcio.it, che non ha i dati (in .gitignore)
# perfettamente aggiornati alcuni giocatori sono gia' fuori (tipo higuahin) o infortunati (tipo zaniolo), 
# quindi dobbiamo rimuovere a mano quelli che non ci interessano 
path_voti = 'Voti_giornate/'
rows_to_skip=[0,1,2,3,4]
# i voti sono quelli delle 38 giornate del campionato 2019/2020

# %%
# struttura della rosa [por, dif, cen, att]
struttura_rosa = np.array([3, 8, 8, 6])

# quali formazioni sono permesse
formazioni = {
    '352': [1, 3, 5, 2],
    '343': [1, 3, 4, 3],
    '442': [1, 4, 4, 2],
    '541': [1, 5, 4, 1],
    '532': [1, 5, 3, 2],
    '433': [1, 4, 3, 3]
    #aggiungere tutte le altre formazioni
}
fasce_goal = np.array([66,  70,  84,  88,  92,  96, 100])
fasce_modificatore = np.array([6. , 6.5, 7. , 7.5, 8. ])
valori_modificatore = np.array([1, 3, 5, 6, 8])

N_squadre = 8

# quanti campionati simulare
N_campionati = 1

[teams, team_names] = names(N_squadre) # output ridondanti ma mi seccavo modificare il resto

# %%
rose_best, classifica_best, classifica_q_best = main_model(N_campionati, struttura_rosa, team_names, teams, quotazioni, path_voti, N_squadre, valori_modificatore, fasce_modificatore, fasce_goal, formazioni)
# Out:
# Campionato attuale:1

# %%
classifica_best
# Out:
#         tot
# Team 1   60
# Team 2   41
# Team 3   32
# Team 4   31
# Team 5   63
# Team 6   43
# Team 7   42
# Team 8   54

# %%
rose_best
# Out:
#               Team 1        Team 2          Team 3         Team 4  \
# 0             SIRIGU     PAU LOPEZ            SEPE         CORDAZ
# 1          SILVESTRI   CARNESECCHI        MONTIPO'          MERET
# 2          SKORUPSKI        OSPINA            ZOET     HANDANOVIC
# 3             LIROLA        ROMERO            RADU          DIJKS
# 4               IZZO     CHIELLINI  STRYGER LARSEN         ACERBI
# 5         SPINAZZOLA          GLIK   PEZZELLA GER.        BASTONI
# 6         MILENKOVIC         YOUNG         CACERES        YOSHIDA
# 7         CEPPITELLI      PALOMINO       MARIO RUI     MAKSIMOVIC
# 8        DANILO LAR.      NUYTINCK            BANI       HATEBOER
# 9            ANSALDI     MUSACCHIO         AUGELLO          KJAER
# 10           BIRAGHI        COLLEY     ALEX SANDRO         HAKIMI
# 11           SORIANO  LUIS ALBERTO          ARTHUR        BENASSI
# 12           AMRABAT       LINETTY           VIOLA           ZAJC
# 13         BENTANCUR     LOCATELLI         DIAZ B.        LAZZARI
# 14        CASTILLEJO     MIRANCHUK           BARAK         NANDEZ
# 15  MILINKOVIC-SAVIC        RAMSEY     BONAVENTURA        PERISIC
# 16           PEROTTI        JANKTO         DE ROON        BARELLA
# 17    PELLEGRINI LO.   MALINOVSKYI      CALHANOGLU        ZANIOLO
# 18             KUCKA       PEREIRO          KURTIC  DOUGLAS COSTA
# 19           SIMEONE          SIMY         LASAGNA         RIBERY
# 20           CAICEDO       RONALDO           MILIK        SANCHEZ
# 21       IBRAHIMOVIC       BELOTTI            ZAZA        KOUAME'
# 22             PEDRO       OSIMHEN         BERARDI           BOGA
# 23       IAGO FALQUE        MURIEL         INSIGNE          REBIC
# 24          GERVINHO        CORREA           OKAKA    MARTINEZ L.
#
#            Team 5       Team 6        Team 7        Team 8
# 0   DONNARUMMA G.     ROSSI F.     STRAKOSHA        AUDERO
# 1         GOLLINI     SZCZESNY    SPORTIELLO         MUSSO
# 2          CRAGNO    DRAGOWSKI         PERIN      CONSIGLI
# 3           GODIN  LUIZ FELIPE        IBANEZ   BRUNO ALVES
# 4    HERNANDEZ T.      MANOLAS      DJIMSITI      SKRINIAR
# 5     BRUNO PERES      KOLAROV    FERRARI G.     KOULIBALY
# 6       ROMAGNOLI      DE LIGT      CUADRADO  RODRIGUEZ R.
# 7        GAGLIOLO     TOMIYASU       FARAONI       DE VRIJ
# 8      D'AMBROSIO       GOSENS      KUMBULLA      RRAHMANI
# 9        N'KOULOU      VOJVODA       MANCINI    DI LORENZO
# 10       CRISCITO        TOLOI       BONUCCI       DARMIAN
# 11       VERETOUT       BENALI          RUIZ         VERDI
# 12     KULUSEVSKI      RAMIREZ     ZIELINSKI   CASTROVILLI
# 13        DE PAUL       SOTTIL  BERNARDESCHI           ROG
# 14         TONALI        ELMAS      DJURICIC        RABIOT
# 15       ZACCAGNI      KESSIE'       PASALIC       ERIKSEN
# 16     MKHITARYAN     BROZOVIC        CHIESA         GOMEZ
# 17         PULGAR      FREULER         UNDER       LAZOVIC
# 18       POLITANO      DIAWARA         SENSI    NAINGGOLAN
# 19   QUAGLIARELLA     VLAHOVIC        CAPUTO      IMMOBILE
# 20         ILICIC    PAVOLETTI     ZAPATA D.   RAFAEL LEAO
# 21          DZEKO      CUTRONE     BONAZZOLI        LUKAKU
# 22    NESTOROVSKI     ORSOLINI       INGLESE       HIGUAIN
# 23      CORNELIUS   JOAO PEDRO      LAPADULA        BARROW
# 24         DYBALA   GABBIADINI       MERTENS       PETAGNA

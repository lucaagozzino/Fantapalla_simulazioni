# %%
import numpy as np
import pandas as pd
from Utilities_fantapalla import main_model, names

quotazioni = pd.read_csv ('Quotazioni_Fantacalcio.csv')
# il file quotazioni contiene la lista dei giocatori direttamente da fantacalcio.it, che non ha i dati 
# perfettamente aggiornati alcuni giocatori sono gia' fuori (tipo higuahin) o infortunati (tipo zaniolo), 
# quindi dobbiamo rimuovere a mano quelli che non ci interessano 
path_voti = 'Voti_giornate/'
rows_to_skip=[0,1,2,3,4]
# i voti sono quelli delle 38 giornate del campionato 2019/2020

# %%
# struttura della rosa [por, dif, cen, att]
struttura_rosa = np.array([3, 8, 8, 6])

# quali formazioni sono permesse
formazioni = {
    '352': [1, 3, 5, 2],
    '343': [1, 3, 4, 3],
    '442': [1, 4, 4, 2],
    '541': [1, 5, 4, 1],
    '532': [1, 5, 3, 2],
    '433': [1, 4, 3, 3]
    #aggiungere tutte le altre formazioni
}
fasce_goal = np.array([66,  70,  84,  88,  92,  96, 100])
fasce_modificatore = np.array([6. , 6.5, 7. , 7.5, 8. ])
valori_modificatore = np.array([1, 3, 5, 6, 8])

N_squadre = 8

[teams, team_names] = names(N_squadre)

# %%
rose_best, classifica_best, classifica_q_best = main_model(200, struttura_rosa, team_names, teams, quotazioni, path_voti, N_squadre, valori_modificatore, fasce_modificatore, fasce_goal, formazioni)
# Out:
# Campionato attuale:16

# %%
classifica_best
# Out:
#         tot
# Team 1   51
# Team 2   47
# Team 3   41
# Team 4   53
# Team 5   53
# Team 6   53
# Team 7   31
# Team 8   29

# %%
rose_best
# Out:
#          Team 1      Team 2          Team 3        Team 4            Team 5  \
# 0     SILVESTRI      AUDERO        ROSSI F.    HANDANOVIC            CRAGNO
# 1     SKORUPSKI    MONTIPO'          OSPINA          ZOET             PERIN
# 2        SIRIGU   STRAKOSHA            SEPE      SZCZESNY           GOLLINI
# 3      CUADRADO     MANCINI         AUGELLO          RADU        FERRARI G.
# 4       DARMIAN    HATEBOER       MARIO RUI         GODIN            IBANEZ
# 5      RRAHMANI     CACERES          GOSENS       BONUCCI             KJAER
# 6       DE VRIJ     MANOLAS     DANILO LAR.  RODRIGUEZ R.        CEPPITELLI
# 7       BASTONI    CRISCITO        KUMBULLA     MUSACCHIO           FARAONI
# 8    SPINAZZOLA      ROMERO            IZZO      NUYTINCK             DIJKS
# 9        COLLEY     KOLAROV            GLIK       ANSALDI          DJIMSITI
# 10     GAGLIOLO     YOSHIDA   PEZZELLA GER.       DE LIGT            ACERBI
# 11      PERISIC       ELMAS        ZACCAGNI       RAMIREZ        NAINGGOLAN
# 12          ROG       GOMEZ       MIRANCHUK         KUCKA           LAZOVIC
# 13       RABIOT        ZAJC  PELLEGRINI LO.       SORIANO           FREULER
# 14      LINETTY  KULUSEVSKI         BENASSI  LUIS ALBERTO              RUIZ
# 15       PULGAR       VIOLA      CALHANOGLU         UNDER           DIAWARA
# 16      BARELLA      CHIESA         ERIKSEN       KESSIE'  MILINKOVIC-SAVIC
# 17  BONAVENTURA  MKHITARYAN          JANKTO   CASTROVILLI      BERNARDESCHI
# 18      DE PAUL     LAZZARI          SOTTIL     LOCATELLI           AMRABAT
# 19  IBRAHIMOVIC     SANCHEZ           MILIK        CAPUTO           INGLESE
# 20       ILICIC        BOGA        IMMOBILE       SIMEONE             DZEKO
# 21  MARTINEZ L.      MURIEL     RAFAEL LEAO       LASAGNA       NESTOROVSKI
# 22      BELOTTI   CORNELIUS        LAPADULA       PETAGNA      QUAGLIARELLA
# 23      RONALDO    VLAHOVIC          CORREA   IAGO FALQUE        JOAO PEDRO
# 24       LUKAKU       OKAKA         MERTENS        BARROW            RIBERY
#
#             Team 6         Team 7       Team 8
# 0    DONNARUMMA G.      PAU LOPEZ  CARNESECCHI
# 1         CONSIGLI     SPORTIELLO        MUSSO
# 2        DRAGOWSKI          MERET       CORDAZ
# 3         SKRINIAR     D'AMBROSIO  BRUNO PERES
# 4        KOULIBALY      ROMAGNOLI  ALEX SANDRO
# 5         TOMIYASU      CHIELLINI      VOJVODA
# 6       MILENKOVIC       PALOMINO         BANI
# 7           LIROLA          YOUNG        TOLOI
# 8      BRUNO ALVES     DI LORENZO   MAKSIMOVIC
# 9   STRYGER LARSEN   HERNANDEZ T.  LUIZ FELIPE
# 10          HAKIMI        BIRAGHI     N'KOULOU
# 11          NANDEZ  DOUGLAS COSTA       ARTHUR
# 12        BROZOVIC     CASTILLEJO      DIAZ B.
# 13       BENTANCUR        PASALIC       TONALI
# 14        VERETOUT        PEREIRO  MALINOVSKYI
# 15         DE ROON       DJURICIC    ZIELINSKI
# 16          RAMSEY         KURTIC        VERDI
# 17           BARAK          SENSI     POLITANO
# 18          BENALI        PEROTTI      ZANIOLO
# 19      GABBIADINI      BONAZZOLI       DYBALA
# 20       ZAPATA D.        KOUAME'      INSIGNE
# 21            SIMY        CAICEDO    PAVOLETTI
# 22            ZAZA        BERARDI      HIGUAIN
# 23        ORSOLINI        CUTRONE        REBIC
# 24           PEDRO       GERVINHO      OSIMHEN

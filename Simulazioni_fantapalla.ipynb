# %%
import numpy as np
import pandas as pd
from Utilities_fantapalla import main_model, names

quotazioni = pd.read_csv ('Quotazioni_Fantacalcio.csv')

#test 1

# %%
struttura_rosa = np.array([3, 8, 8, 6])
#this must contain all the allowed schemes

formazioni = {
    '352': [1, 3, 5, 2],
    '343': [1, 3, 4, 3],
    '442': [1, 4, 4, 2],
    '541': [1, 5, 4, 1],
    '532': [1, 5, 3, 2],
    '433': [1, 4, 3, 3]
    #aggiungere tutte le altre formazioni
}
fasce_goal = np.array([66,  70,  84,  88,  92,  96, 100])
fasce_modificatore = np.array([6. , 6.5, 7. , 7.5, 8. ])
valori_modificatore = np.array([1, 3, 5, 6, 8])
rows_to_skip=[0,1,2,3,4]

N_squadre = 8

[teams, team_names] = names(N_squadre)
team_names
# Out:
# ['Team 1',
#  'Team 2',
#  'Team 3',
#  'Team 4',
#  'Team 5',
#  'Team 6',
#  'Team 7',
#  'Team 8']

# %%
rose_best, classifica_best, classifica_q_best = main_model(1, struttura_rosa, team_names, teams, quotazioni, path = '/Voti_giornata', num_squadre = N_squadre)

# %%
rose_best
# Out:
#         Team 1          Team 2        Team 3         Team 4            Team 5  \
# 0        MUSSO         GOLLINI        CRAGNO      PAU LOPEZ            CORDAZ
# 1       AUDERO     CARNESECCHI     SKORUPSKI       SZCZESNY            OSPINA
# 2         SEPE        MONTIPO'          ZOET      DRAGOWSKI          ROSSI F.
# 3   CEPPITELLI       CHIELLINI         TOLOI     D'AMBROSIO        MILENKOVIC
# 4      YOSHIDA        DJIMSITI     MUSACCHIO       KUMBULLA         MARIO RUI
# 5         RADU         CACERES          GLIK        FARAONI           DE LIGT
# 6      VOJVODA    HERNANDEZ T.      RRAHMANI  PEZZELLA GER.           MANOLAS
# 7       COLLEY          HAKIMI   BRUNO PERES         ROMERO          GAGLIOLO
# 8       IBANEZ    RODRIGUEZ R.    MAKSIMOVIC        KOLAROV         ROMAGNOLI
# 9       LIROLA           GODIN      N'KOULOU       HATEBOER          NUYTINCK
# 10    CRISCITO      FERRARI G.       BIRAGHI    LUIZ FELIPE           AUGELLO
# 11   BENTANCUR         ZANIOLO   MALINOVSKYI            ROG           RAMIREZ
# 12  MKHITARYAN           BARAK  LUIS ALBERTO          ELMAS           LINETTY
# 13        ZAJC          PULGAR    CALHANOGLU          GOMEZ            BENALI
# 14     LAZZARI          KURTIC      DJURICIC     NAINGGOLAN     DOUGLAS COSTA
# 15     KESSIE'     BONAVENTURA        ARTHUR     KULUSEVSKI            RABIOT
# 16     PEREIRO  PELLEGRINI LO.       BARELLA        PASALIC  MILINKOVIC-SAVIC
# 17     DIAZ B.     CASTROVILLI       DE PAUL       VERETOUT           FREULER
# 18      RAMSEY          TONALI       BENASSI   BERNARDESCHI           SORIANO
# 19      DYBALA          CAPUTO         MILIK      PAVOLETTI           RONALDO
# 20        ZAZA           OKAKA    JOAO PEDRO         LUKAKU             DZEKO
# 21   BONAZZOLI         OSIMHEN   IBRAHIMOVIC         CORREA           SIMEONE
# 22     BERARDI         HIGUAIN    GABBIADINI    RAFAEL LEAO         CORNELIUS
# 23      ILICIC    QUAGLIARELLA       INSIGNE        SANCHEZ            RIBERY
# 24       PEDRO         BELOTTI      GERVINHO           SIMY           CUTRONE
#
#             Team 6         Team 7       Team 8
# 0         CONSIGLI  DONNARUMMA G.   HANDANOVIC
# 1        SILVESTRI     SPORTIELLO       SIRIGU
# 2        STRAKOSHA          MERET        PERIN
# 3         TOMIYASU      KOULIBALY  ALEX SANDRO
# 4          MANCINI        BASTONI     CUADRADO
# 5         SKRINIAR     SPINAZZOLA        KJAER
# 6          DE VRIJ           IZZO       ACERBI
# 7   STRYGER LARSEN         GOSENS      ANSALDI
# 8         PALOMINO          YOUNG      DARMIAN
# 9             BANI          DIJKS      BONUCCI
# 10     BRUNO ALVES     DI LORENZO  DANILO LAR.
# 11        BROZOVIC          VERDI       NANDEZ
# 12          SOTTIL        PERISIC      DE ROON
# 13           VIOLA       ZACCAGNI       JANKTO
# 14           SENSI     CASTILLEJO        UNDER
# 15            RUIZ      MIRANCHUK    LOCATELLI
# 16         ERIKSEN          KUCKA      LAZOVIC
# 17         AMRABAT        PEROTTI      DIAWARA
# 18       ZIELINSKI         CHIESA     POLITANO
# 19     MARTINEZ L.    NESTOROVSKI      CAICEDO
# 20       ZAPATA D.        LASAGNA     VLAHOVIC
# 21          BARROW        MERTENS  IAGO FALQUE
# 22          MURIEL       IMMOBILE     LAPADULA
# 23        ORSOLINI        KOUAME'         BOGA
# 24           REBIC        PETAGNA      INGLESE

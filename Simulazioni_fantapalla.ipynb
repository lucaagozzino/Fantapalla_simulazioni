# %%
#test github 2
import numpy as np
import pandas as pd
from Utilities_fantapalla import main_model, names, styling_rows, ruoli, FC_colors

# %%
quotazioni = pd.read_csv ('Quotazioni_Fantacalcio.csv')
# il file quotazioni contiene la lista dei giocatori direttamente da fantacalcio.it, che non ha i dati (in .gitignore)
# perfettamente aggiornati alcuni giocatori sono gia' fuori (tipo higuahin) o infortunati (tipo zaniolo), 
# quindi dobbiamo rimuovere a mano quelli che non ci interessano 
path_voti = 'Voti_giornate/'
rows_to_skip=[0,1,2,3,4]
# i voti sono quelli delle 38 giornate del campionato 2019/2020

# %%
# struttura della rosa [por, dif, cen, att]
struttura_rosa = np.array([3, 8, 8, 6])

# quali formazioni sono permesse
formazioni = {
    '352': [1, 3, 5, 2],
    '343': [1, 3, 4, 3],
    '442': [1, 4, 4, 2],
    '541': [1, 5, 4, 1],
    '532': [1, 5, 3, 2],
    '433': [1, 4, 3, 3]
    #aggiungere tutte le altre formazioni
}
fasce_goal = np.array([66,  70,  84,  88,  92,  96, 100])
fasce_modificatore = np.array([6. , 6.5, 7. , 7.5, 8. ])
valori_modificatore = np.array([1, 3, 5, 6, 8])

N_squadre = 8

# quanti campionati simulare
N_campionati = 2

[teams, team_names] = names(N_squadre) # output ridondanti ma mi seccavo modificare il resto
roles =  ruoli(struttura_rosa)

# %%
rose_best, classifica_best, classifica_q_best = main_model(N_campionati, struttura_rosa, team_names, teams, quotazioni, path_voti, N_squadre, valori_modificatore, fasce_modificatore, fasce_goal, formazioni)
# Out:
# 100% (2 of 2) |##########################| Elapsed Time: 0:01:58 Time:  0:01:58

# %%
classifica_best
# Out:
#         tot
# Team 1   49
# Team 2   53
# Team 3   37
# Team 4   56
# Team 5   56
# Team 6   34
# Team 7   23
# Team 8   50

# %%
rose_best
# Out:
#           Team 1            Team 2       Team 3          Team 4       Team 5  \
# 0      SILVESTRI              SEPE         ZOET           PERIN    DRAGOWSKI
# 1       CONSIGLI          ROSSI F.    STRAKOSHA           MUSSO   HANDANOVIC
# 2         CORDAZ            SIRIGU      GOLLINI     CARNESECCHI    PAU LOPEZ
# 3        AUGELLO           CACERES     TOMIYASU           GODIN    KOULIBALY
# 4          TOLOI              RADU  ALEX SANDRO  STRYGER LARSEN   MILENKOVIC
# 5    BRUNO PERES      RODRIGUEZ R.      KOLAROV          LIROLA     NUYTINCK
# 6     CEPPITELLI          SKRINIAR     N'KOULOU         MANCINI  LUIZ FELIPE
# 7         ROMERO          HATEBOER      DE VRIJ       ROMAGNOLI      DE LIGT
# 8    DANILO LAR.              BANI     CUADRADO     BRUNO ALVES    MARIO RUI
# 9   HERNANDEZ T.           MANOLAS   D'AMBROSIO          GOSENS      BONUCCI
# 10       FARAONI          CRISCITO      BASTONI      MAKSIMOVIC         IZZO
# 11     ZIELINSKI          ZACCAGNI       NANDEZ           VERDI          ROG
# 12   MALINOVSKYI        NAINGGOLAN      KESSIE'  PELLEGRINI LO.       RABIOT
# 13   BONAVENTURA         BENTANCUR      LAZZARI           BARAK   CALHANOGLU
# 14     LOCATELLI  MILINKOVIC-SAVIC   MKHITARYAN        DJURICIC         RUIZ
# 15         GOMEZ            TONALI      PEREIRO    LUIS ALBERTO      DE ROON
# 16       PASALIC            KURTIC        ELMAS          SOTTIL      PERISIC
# 17      VERETOUT            JANKTO      LINETTY          CHIESA   CASTILLEJO
# 18       DIAWARA             KUCKA   KULUSEVSKI         DE PAUL      RAMIREZ
# 19          ZAZA           PETAGNA      INGLESE        ORSOLINI        DZEKO
# 20       CUTRONE           BELOTTI    BONAZZOLI    QUAGLIARELLA     LAPADULA
# 21      IMMOBILE            LUKAKU    PAVOLETTI     NESTOROVSKI   JOAO PEDRO
# 22   IBRAHIMOVIC           SIMEONE      HIGUAIN           OKAKA   GABBIADINI
# 23        ILICIC           INSIGNE  RAFAEL LEAO          DYBALA        PEDRO
# 24   IAGO FALQUE             MILIK       BARROW       ZAPATA D.       CAPUTO
#
#            Team 6         Team 7         Team 8
# 0       SKORUPSKI       MONTIPO'       SZCZESNY
# 1          CRAGNO          MERET     SPORTIELLO
# 2   DONNARUMMA G.         OSPINA         AUDERO
# 3        DJIMSITI       KUMBULLA        ANSALDI
# 4          IBANEZ        YOSHIDA        DARMIAN
# 5       MUSACCHIO        VOJVODA          DIJKS
# 6        PALOMINO        BIRAGHI  PEZZELLA GER.
# 7           YOUNG         COLLEY     DI LORENZO
# 8            GLIK          KJAER       RRAHMANI
# 9        GAGLIOLO     FERRARI G.     SPINAZZOLA
# 10         ACERBI      CHIELLINI         HAKIMI
# 11         BENALI        SORIANO         ARTHUR
# 12       POLITANO        ZANIOLO        AMRABAT
# 13      MIRANCHUK        DIAZ B.        LAZOVIC
# 14         PULGAR         RAMSEY          SENSI
# 15        PEROTTI           ZAJC          VIOLA
# 16        ERIKSEN  DOUGLAS COSTA        FREULER
# 17   BERNARDESCHI    CASTROVILLI          UNDER
# 18        BENASSI       BROZOVIC        BARELLA
# 19      CORNELIUS        KOUAME'           SIMY
# 20       VLAHOVIC        MERTENS       GERVINHO
# 21        CAICEDO          REBIC         RIBERY
# 22        RONALDO        OSIMHEN         MURIEL
# 23        LASAGNA         CORREA           BOGA
# 24        BERARDI    MARTINEZ L.        SANCHEZ

# %%
#rose_best.to_pickle('rose_best.pkl')
rose_best = pd.read_pickle('rose_best.pkl')

# %%
FC_colors(rose_best, struttura_rosa)
# Out:
# <style  type="text/css" >
#     #T_48dcdcda_f77b_11ea_b30b_acde48001122row0_col0 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row0_col1 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row0_col2 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row0_col3 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row0_col4 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row0_col5 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row0_col6 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row0_col7 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row1_col0 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row1_col1 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row1_col2 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row1_col3 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row1_col4 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row1_col5 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row1_col6 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row1_col7 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row2_col0 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row2_col1 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row2_col2 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row2_col3 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row2_col4 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row2_col5 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row2_col6 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row2_col7 {
#             background-color:  rgba(249,168,38,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row3_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row3_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row3_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row3_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row3_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row3_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row3_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row3_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row4_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row4_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row4_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row4_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row4_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row4_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row4_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row4_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row5_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row5_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row5_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row5_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row5_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row5_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row5_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row5_col7 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row6_col0 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row6_col1 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row6_col2 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row6_col3 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row6_col4 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row6_col5 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row6_col6 {
#             background-color:  rgba(46,125,51,.5);
#              color:  black;
#         }    #T_48dcdcda_f77b_11ea_b30b_acde48001122row6_col7 {
#             background-color:
